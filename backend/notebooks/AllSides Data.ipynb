# %%
sources = [{"name": "ABC News", "allsides_page": "https://www.allsides.com/news-source/abc-news-media-bias", "bias": "left-center", "agree": 10380, "disagree": 7721, "total_votes": 18101, "agree_ratio": 1.3443854423002202, "agreeance_text": "somewhat agrees", "website": "http://abcnews.go.com/"}, {"name": "Al Jazeera", "allsides_page": "https://www.allsides.com/news-source/al-jazeera-america", "bias": "center", "agree": 2852, "disagree": 4207, "total_votes": 7059, "agree_ratio": 0.6779177561207511, "agreeance_text": "somewhat disagrees"}, {"name": "AlterNet", "allsides_page": "https://www.allsides.com/news-source/alternet", "bias": "left", "agree": 1785, "disagree": 672, "total_votes": 2457, "agree_ratio": 2.65625, "agreeance_text": "strongly agrees", "website": "http://www.alternet.org/"}, {"name": "American Spectator", "allsides_page": "https://www.allsides.com/news-source/american-spectator", "bias": "right", "agree": 5327, "disagree": 2258, "total_votes": 7585, "agree_ratio": 2.3591674047829936, "agreeance_text": "strongly agrees", "website": "http://spectator.org/"}, {"name": "Associated Press", "allsides_page": "https://www.allsides.com/news-source/associated-press-media-bias", "bias": "center", "agree": 5668, "disagree": 3939, "total_votes": 9607, "agree_ratio": 1.438943894389439, "agreeance_text": "somewhat agrees", "website": "http://www.ap.org/"}, {"name": "Axios", "allsides_page": "https://www.allsides.com/news-source/axios", "bias": "center", "agree": 935, "disagree": 1051, "total_votes": 1986, "agree_ratio": 0.8896289248334919, "agreeance_text": "somewhat disagrees"}, {"name": "BBC News", "allsides_page": "https://www.allsides.com/news-source/bbc-news-media-bias", "bias": "center", "agree": 8687, "disagree": 8070, "total_votes": 16757, "agree_ratio": 1.076456009913259, "agreeance_text": "somewhat agrees", "website": "http://www.bbc.com/"}, {"name": "Bloomberg", "allsides_page": "https://www.allsides.com/news-source/bloomberg-media-bias", "bias": "center", "agree": 4785, "disagree": 5453, "total_votes": 10238, "agree_ratio": 0.8774986246103063, "agreeance_text": "somewhat disagrees", "website": "http://www.bloomberg.com/"}, {"name": "Breitbart News", "allsides_page": "https://www.allsides.com/news-source/breitbart", "bias": "right", "agree": 13295, "disagree": 7095, "total_votes": 20390, "agree_ratio": 1.8738548273431994, "agreeance_text": "agrees", "website": "http://www.breitbart.com/"}, {"name": "BuzzFeed News", "allsides_page": "https://www.allsides.com/news-source/buzzfeed-media-bias", "bias": "left-center", "agree": 3616, "disagree": 4973, "total_votes": 8589, "agree_ratio": 0.7271264830082446, "agreeance_text": "somewhat disagrees", "website": "http://Buzzfeed.com"}, {"name": "CBN", "allsides_page": "https://www.allsides.com/news-source/cbn", "bias": "right", "agree": 5491, "disagree": 2901, "total_votes": 8392, "agree_ratio": 1.8927955877283695, "agreeance_text": "agrees", "website": "http://www.cbn.com/"}, {"name": "CBS News", "allsides_page": "https://www.allsides.com/news-source/cbs-news-media-bias", "bias": "left-center", "agree": 5022, "disagree": 4295, "total_votes": 9317, "agree_ratio": 1.169266589057043, "agreeance_text": "somewhat agrees", "website": "http://www.cbs.com/"}, {"name": "Chicago Tribune", "allsides_page": "https://www.allsides.com/news-source/chicago-tribune", "bias": "center", "agree": 1500, "disagree": 2617, "total_votes": 4117, "agree_ratio": 0.573175391669851, "agreeance_text": "disagrees", "website": "http://www.chicagotribune.com/"}, {"name": "Christian Science Monitor", "allsides_page": "https://www.allsides.com/news-source/christian-science-monitor", "bias": "center", "agree": 7575, "disagree": 10406, "total_votes": 17981, "agree_ratio": 0.7279454161060926, "agreeance_text": "somewhat disagrees", "website": "http://www.csmonitor.com/"}, {"name": "CNN (Web News)", "allsides_page": "https://www.allsides.com/news-source/cnn-media-bias", "bias": "left-center", "agree": 24654, "disagree": 25487, "total_votes": 50141, "agree_ratio": 0.9673166712441637, "agreeance_text": "somewhat disagrees", "website": "http://www.cnn.com"}, {"name": "CNN - Editorial", "allsides_page": "https://www.allsides.com/news-source/cnn-editorial", "bias": "left", "agree": 5154, "disagree": 1686, "total_votes": 6840, "agree_ratio": 3.0569395017793592, "agreeance_text": "absolutely agrees"}, {"name": "Daily Beast", "allsides_page": "https://www.allsides.com/news-source/daily-beast-media-bias", "bias": "left", "agree": 5204, "disagree": 3694, "total_votes": 8898, "agree_ratio": 1.408770979967515, "agreeance_text": "somewhat agrees", "website": "http://www.thedailybeast.com/"}, {"name": "Daily Kos", "allsides_page": "https://www.allsides.com/news-source/daily-kos", "bias": "left", "agree": 4393, "disagree": 1689, "total_votes": 6082, "agree_ratio": 2.600947306098283, "agreeance_text": "strongly agrees", "website": "http://www.dailykos.com"}, {"name": "Daily Mail", "allsides_page": "https://www.allsides.com/news-source/daily-mail", "bias": "right", "agree": 1303, "disagree": 1088, "total_votes": 2391, "agree_ratio": 1.197610294117647, "agreeance_text": "somewhat agrees", "website": "http://dailymail.co.uk"}, {"name": "Democracy Now", "allsides_page": "https://www.allsides.com/news-source/democracy-now", "bias": "left", "agree": 3822, "disagree": 1581, "total_votes": 5403, "agree_ratio": 2.4174573055028463, "agreeance_text": "strongly agrees", "website": "http://www.democracynow.org/"}, {"name": "FactCheck.org", "allsides_page": "https://www.allsides.com/news-source/factcheckorg-media-bias", "bias": "center", "agree": 4828, "disagree": 3376, "total_votes": 8204, "agree_ratio": 1.430094786729858, "agreeance_text": "somewhat agrees", "website": "http://factcheck.org/"}, {"name": "FiveThirtyEight", "allsides_page": "https://www.allsides.com/news-source/fivethirtyeight-0", "bias": "center", "agree": 2951, "disagree": 1688, "total_votes": 4639, "agree_ratio": 1.7482227488151658, "agreeance_text": "agrees", "website": "http://fivethirtyeight.com/"}, {"name": "Forbes", "allsides_page": "https://www.allsides.com/news-source/forbes", "bias": "center", "agree": 2494, "disagree": 1702, "total_votes": 4196, "agree_ratio": 1.4653349001175089, "agreeance_text": "somewhat agrees", "website": "http://www.forbes.com/"}, {"name": "Fox News", "allsides_page": "https://www.allsides.com/news-source/fox-news-media-bias", "bias": "right-center", "agree": 19271, "disagree": 28881, "total_votes": 48152, "agree_ratio": 0.6672552889442886, "agreeance_text": "disagrees", "website": "http://www.foxnews.com/"}, {"name": "Fox News Editorial", "allsides_page": "https://www.allsides.com/news-source/fox-news-editorial-media-bias", "bias": "right", "agree": 3186, "disagree": 911, "total_votes": 4097, "agree_ratio": 3.497255762897914, "agreeance_text": "absolutely agrees", "website": "http://www.foxnews.com/opinion.html"}, {"name": "HuffPost", "allsides_page": "https://www.allsides.com/news-source/huffpost-media-bias", "bias": "left", "agree": 16956, "disagree": 18814, "total_votes": 35770, "agree_ratio": 0.901243754650792, "agreeance_text": "somewhat disagrees", "website": "http://www.huffingtonpost.com/"}, {"name": "Investor's Business Daily", "allsides_page": "https://www.allsides.com/news-source/investors-business-daily", "bias": "right-center", "agree": 859, "disagree": 709, "total_votes": 1568, "agree_ratio": 1.2115655853314526, "agreeance_text": "somewhat agrees", "website": "http://www.investors.com"}, {"name": "Jacobin", "allsides_page": "https://www.allsides.com/news-source/jacobin-media-bias", "bias": "left", "agree": 231, "disagree": 33, "total_votes": 264, "agree_ratio": 7.0, "agreeance_text": "absolutely agrees", "website": "https://jacobinmag.com/"}, {"name": "Los Angeles Times", "allsides_page": "https://www.allsides.com/news-source/los-angeles-times-bias", "bias": "left-center", "agree": 3415, "disagree": 2619, "total_votes": 6034, "agree_ratio": 1.3039327987781597, "agreeance_text": "somewhat agrees", "website": "http://www.latimes.com/"}, {"name": "Mother Jones", "allsides_page": "https://www.allsides.com/news-source/mother-jones-bias", "bias": "left", "agree": 3501, "disagree": 744, "total_votes": 4245, "agree_ratio": 4.705645161290323, "agreeance_text": "absolutely agrees", "website": "http://www.motherjones.com/"}, {"name": "MSNBC", "allsides_page": "https://www.allsides.com/news-source/msnbc", "bias": "left", "agree": 3825, "disagree": 1499, "total_votes": 5324, "agree_ratio": 2.551701134089393, "agreeance_text": "strongly agrees", "website": "http://www.msnbc.com/"}, {"name": "National Review", "allsides_page": "https://www.allsides.com/news-source/national-review", "bias": "right", "agree": 7430, "disagree": 3638, "total_votes": 11068, "agree_ratio": 2.042330951072018, "agreeance_text": "strongly agrees", "website": "http://www.nationalreview.com/"}, {"name": "NBCNews.com", "allsides_page": "https://www.allsides.com/news-source/nbc-news-media-bias", "bias": "left-center", "agree": 3341, "disagree": 4380, "total_votes": 7721, "agree_ratio": 0.7627853881278539, "agreeance_text": "somewhat disagrees", "website": "http://www.nbcnews.com"}, {"name": "New York Post", "allsides_page": "https://www.allsides.com/news-source/new-york-post", "bias": "right", "agree": 2417, "disagree": 1791, "total_votes": 4208, "agree_ratio": 1.3495254048017866, "agreeance_text": "somewhat agrees", "website": "http://www.nypost.com/"}, {"name": "New York Times - News", "allsides_page": "https://www.allsides.com/news-source/new-york-times", "bias": "left-center", "agree": 13582, "disagree": 22988, "total_votes": 36570, "agree_ratio": 0.5908299982599617, "agreeance_text": "disagrees", "website": "http://www.nytimes.com/"}, {"name": "New York Times - Opinion", "allsides_page": "https://www.allsides.com/news-source/new-york-times-opinion-media-bias", "bias": "left", "agree": 1169, "disagree": 407, "total_votes": 1576, "agree_ratio": 2.8722358722358723, "agreeance_text": "strongly agrees"}, {"name": "Newsmax", "allsides_page": "https://www.allsides.com/news-source/newsmax", "bias": "right", "agree": 6155, "disagree": 8206, "total_votes": 14361, "agree_ratio": 0.7500609310260785, "agreeance_text": "somewhat disagrees", "website": "http://www.newsmax.com/"}, {"name": "Newsweek", "allsides_page": "https://www.allsides.com/news-source/newsweek", "bias": "left-center", "agree": 1689, "disagree": 2117, "total_votes": 3806, "agree_ratio": 0.7978271138403401, "agreeance_text": "somewhat disagrees", "website": "http://www.thedailybeast.com/newsweek.html"}, {"name": "NPR Editorial", "allsides_page": "https://www.allsides.com/news-source/npr-editorial", "bias": "left-center", "agree": 1140, "disagree": 1276, "total_votes": 2416, "agree_ratio": 0.8934169278996865, "agreeance_text": "somewhat disagrees", "website": "https://www.npr.org/sections/opinion/"}, {"name": "NPR News", "allsides_page": "https://www.allsides.com/news-source/npr-media-bias", "bias": "center", "agree": 17371, "disagree": 12325, "total_votes": 29696, "agree_ratio": 1.4094117647058824, "agreeance_text": "somewhat agrees", "website": "http://www.npr.org/"}, {"name": "Politico", "allsides_page": "https://www.allsides.com/news-source/politico-media-bias", "bias": "left-center", "agree": 12187, "disagree": 19735, "total_votes": 31922, "agree_ratio": 0.6175323030149481, "agreeance_text": "disagrees", "website": "http://www.politico.com/"}, {"name": "RealClearPolitics", "allsides_page": "https://www.allsides.com/news-source/real-clear-politics", "bias": "center", "agree": 2273, "disagree": 1806, "total_votes": 4079, "agree_ratio": 1.2585825027685493, "agreeance_text": "somewhat agrees", "website": "http://www.realclearpolitics.com/"}, {"name": "Reason", "allsides_page": "https://www.allsides.com/news-source/reason", "bias": "right-center", "agree": 4328, "disagree": 2928, "total_votes": 7256, "agree_ratio": 1.4781420765027322, "agreeance_text": "somewhat agrees", "website": "http://reason.org/"}, {"name": "Reuters", "allsides_page": "https://www.allsides.com/news-source/reuters", "bias": "center", "agree": 5219, "disagree": 3594, "total_votes": 8813, "agree_ratio": 1.4521424596549806, "agreeance_text": "somewhat agrees", "website": "http://www.reuters.com/"}, {"name": "Salon", "allsides_page": "https://www.allsides.com/news-source/salon", "bias": "left", "agree": 9733, "disagree": 4572, "total_votes": 14305, "agree_ratio": 2.128827646544182, "agreeance_text": "strongly agrees", "website": "http://www.salon.com/"}, {"name": "San Francisco Chronicle", "allsides_page": "https://www.allsides.com/news-source/san-francisco-chronicle", "bias": "left", "agree": 560, "disagree": 210, "total_votes": 770, "agree_ratio": 2.6666666666666665, "agreeance_text": "strongly agrees"}, {"name": "Slate", "allsides_page": "https://www.allsides.com/news-source/slate", "bias": "left", "agree": 2164, "disagree": 2017, "total_votes": 4181, "agree_ratio": 1.0728805156172534, "agreeance_text": "somewhat agrees"}, {"name": "The Atlantic", "allsides_page": "https://www.allsides.com/news-source/atlantic", "bias": "left-center", "agree": 3236, "disagree": 2041, "total_votes": 5277, "agree_ratio": 1.585497305242528, "agreeance_text": "agrees", "website": "http://www.theatlantic.com/"}, {"name": "The Boston Globe", "allsides_page": "https://www.allsides.com/news-source/boston-globe", "bias": "left-center", "agree": 1202, "disagree": 964, "total_votes": 2166, "agree_ratio": 1.2468879668049793, "agreeance_text": "somewhat agrees", "website": "http://www.bostonglobe.com/"}, {"name": "The Daily Caller", "allsides_page": "https://www.allsides.com/news-source/daily-caller", "bias": "right", "agree": 3543, "disagree": 2136, "total_votes": 5679, "agree_ratio": 1.6587078651685394, "agreeance_text": "agrees", "website": "http://dailycaller.com/"}, {"name": "The Daily Wire", "allsides_page": "https://www.allsides.com/news-source/daily-wire", "bias": "right", "agree": 1598, "disagree": 754, "total_votes": 2352, "agree_ratio": 2.1193633952254642, "agreeance_text": "strongly agrees", "website": "http://www.dailywire.com/"}, {"name": "The Economist", "allsides_page": "https://www.allsides.com/news-source/economist", "bias": "left-center", "agree": 1030, "disagree": 2156, "total_votes": 3186, "agree_ratio": 0.4777365491651206, "agreeance_text": "strongly disagrees", "website": "http://www.economist.com/"}, {"name": "The Federalist", "allsides_page": "https://www.allsides.com/news-source/federalist", "bias": "right", "agree": 1638, "disagree": 972, "total_votes": 2610, "agree_ratio": 1.6851851851851851, "agreeance_text": "agrees", "website": "http://thefederalist.com/"}, {"name": "The Guardian", "allsides_page": "https://www.allsides.com/news-source/guardian", "bias": "left-center", "agree": 4946, "disagree": 3066, "total_votes": 8012, "agree_ratio": 1.6131767775603392, "agreeance_text": "agrees", "website": "https://www.theguardian.com/us"}, {"name": "The Hill", "allsides_page": "https://www.allsides.com/news-source/hill-media-bias", "bias": "center", "agree": 5986, "disagree": 7492, "total_votes": 13478, "agree_ratio": 0.7989855846235985, "agreeance_text": "somewhat disagrees"}, {"name": "The Intercept", "allsides_page": "https://www.allsides.com/news-source/intercept", "bias": "left", "agree": 665, "disagree": 468, "total_votes": 1133, "agree_ratio": 1.420940170940171, "agreeance_text": "somewhat agrees", "website": "https://theintercept.com"}, {"name": "The Libertarian Republic", "allsides_page": "https://www.allsides.com/news-source/libertarian-republic", "bias": "right-center", "agree": 618, "disagree": 538, "total_votes": 1156, "agree_ratio": 1.1486988847583643, "agreeance_text": "somewhat agrees", "website": "http://thelibertarianrepublic.com/"}, {"name": "The Nation", "allsides_page": "https://www.allsides.com/news-source/nation", "bias": "left", "agree": 667, "disagree": 211, "total_votes": 878, "agree_ratio": 3.161137440758294, "agreeance_text": "absolutely agrees", "website": "http://www.thenation.com"}, {"name": "The New Yorker", "allsides_page": "https://www.allsides.com/news-source/new-yorker", "bias": "left", "agree": 1334, "disagree": 468, "total_votes": 1802, "agree_ratio": 2.8504273504273505, "agreeance_text": "strongly agrees"}, {"name": "The Weekly Standard", "allsides_page": "https://www.allsides.com/news-source/weekly-standard", "bias": "right", "agree": 1100, "disagree": 643, "total_votes": 1743, "agree_ratio": 1.7107309486780715, "agreeance_text": "agrees", "website": "http://www.weeklystandard.com/"}, {"name": "TheBlaze.com", "allsides_page": "https://www.allsides.com/news-source/theblaze-bias", "bias": "right", "agree": 10698, "disagree": 5554, "total_votes": 16252, "agree_ratio": 1.9261793302124595, "agreeance_text": "agrees", "website": "http://www.theblaze.com/"}, {"name": "ThinkProgress", "allsides_page": "https://www.allsides.com/news-source/thinkprogress-bias", "bias": "left", "agree": 2108, "disagree": 683, "total_votes": 2791, "agree_ratio": 3.0863836017569546, "agreeance_text": "absolutely agrees", "website": "http://thinkprogress.org/"}, {"name": "Time Magazine", "allsides_page": "https://www.allsides.com/news-source/time-magazine-news-media-bias", "bias": "left-center", "agree": 3327, "disagree": 2831, "total_votes": 6158, "agree_ratio": 1.1752031084422465, "agreeance_text": "somewhat agrees", "website": "http://www.time.com/time/"}, {"name": "Townhall", "allsides_page": "https://www.allsides.com/news-source/townhall-bias", "bias": "right", "agree": 8250, "disagree": 13099, "total_votes": 21349, "agree_ratio": 0.6298190701580273, "agreeance_text": "disagrees", "website": "http://townhall.com/"}, {"name": "U.S. News & World Report", "allsides_page": "https://www.allsides.com/news-source/us-news-and-world-report", "bias": "left-center", "agree": 1228, "disagree": 1447, "total_votes": 2675, "agree_ratio": 0.848652384243262, "agreeance_text": "somewhat disagrees", "website": "http://www.usnews.com/"}, {"name": "USA TODAY", "allsides_page": "https://www.allsides.com/news-source/usa-today-media-bias", "bias": "center", "agree": 11260, "disagree": 8403, "total_votes": 19663, "agree_ratio": 1.3399976198976555, "agreeance_text": "somewhat agrees", "website": "http://www.usatoday.com/"}, {"name": "Vanity Fair", "allsides_page": "https://www.allsides.com/news-source/vanity-fair", "bias": "left-center", "agree": 2798, "disagree": 1815, "total_votes": 4613, "agree_ratio": 1.5415977961432508, "agreeance_text": "agrees", "website": "http://www.vanityfair.com/"}, {"name": "Vox", "allsides_page": "https://www.allsides.com/news-source/vox-news-media-bias", "bias": "left", "agree": 9026, "disagree": 11396, "total_votes": 20422, "agree_ratio": 0.7920322920322921, "agreeance_text": "somewhat disagrees", "website": "http://www.vox.com"}, {"name": "Wall Street Journal - Editorial", "allsides_page": "https://www.allsides.com/news-source/wall-street-journal-opinion", "bias": "right-center", "agree": 3940, "disagree": 3124, "total_votes": 7064, "agree_ratio": 1.2612035851472472, "agreeance_text": "somewhat agrees", "website": "http://online.wsj.com/public/page/news-opinion-commentary.html"}, {"name": "Wall Street Journal - News", "allsides_page": "https://www.allsides.com/news-source/wall-street-journal-media-bias", "bias": "center", "agree": 10939, "disagree": 16669, "total_votes": 27608, "agree_ratio": 0.6562481252624632, "agreeance_text": "disagrees", "website": "http://online.wsj.com/"}, {"name": "Washington Examiner", "allsides_page": "https://www.allsides.com/news-source/washington-examiner", "bias": "right-center", "agree": 3421, "disagree": 1911, "total_votes": 5332, "agree_ratio": 1.7901622187336472, "agreeance_text": "agrees", "website": "http://washingtonexaminer.com/"}, {"name": "Washington Post", "allsides_page": "https://www.allsides.com/news-source/washington-post-media-bias", "bias": "left-center", "agree": 22483, "disagree": 13675, "total_votes": 36158, "agree_ratio": 1.6440950639853749, "agreeance_text": "agrees", "website": "http://www.washingtonpost.com/regional"}, {"name": "Washington Times", "allsides_page": "https://www.allsides.com/news-source/washington-times-bias", "bias": "right-center", "agree": 19847, "disagree": 9928, "total_votes": 29775, "agree_ratio": 1.9990934730056407, "agreeance_text": "agrees", "website": "http://www.washingtontimes.com/"}]

# %%
for source in sources:
    print (source["name"])
# Out:
# ABC News
# Al Jazeera
# AlterNet
# American Spectator
# Associated Press
# Axios
# BBC News
# Bloomberg
# Breitbart News
# BuzzFeed News
# CBN
# CBS News
# Chicago Tribune
# Christian Science Monitor
# CNN (Web News)
# CNN - Editorial
# Daily Beast
# Daily Kos
# Daily Mail
# Democracy Now
# FactCheck.org
# FiveThirtyEight
# Forbes
# Fox News
# Fox News Editorial
# HuffPost
# Investor's Business Daily
# Jacobin
# Los Angeles Times
# Mother Jones
# MSNBC
# National Review
# NBCNews.com
# New York Post
# New York Times - News
# New York Times - Opinion
# Newsmax
# Newsweek
# NPR Editorial
# NPR News
# Politico
# RealClearPolitics
# Reason
# Reuters
# Salon
# San Francisco Chronicle
# Slate
# The Atlantic
# The Boston Globe
# The Daily Caller
# The Daily Wire
# The Economist
# The Federalist
# The Guardian
# The Hill
# The Intercept
# The Libertarian Republic
# The Nation
# The New Yorker
# The Weekly Standard
# TheBlaze.com
# ThinkProgress
# Time Magazine
# Townhall
# ...

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('~/Desktop/allsides.csv')

# %%
print (data['name'].unique())
# Out:
# ['The Texas Observer' 'ABC News' 'Al Jazeera' 'AllSides'
#  'AllSides Community' 'AlterNet' 'American Spectator' 'American Thinker'
#  'Aquinas College Saint' 'Arkansas Democrat-Gazette' 'Associated Press'
#  'Atlanta Journal-Constitution' 'Austin American-Statesman' 'Axios'
#  'Barnstable Patriot' 'BBC News' 'Bearing Drift' 'Bloomberg'
#  'Blue Virginia' 'Boing Boing' 'Boston Herald' 'Boston Herald Editorial'
#  'Bowling Green Daily News' 'Breitbart News' 'Business Insider' 'Bustle'
#  'BuzzFeed News' 'C-SPAN' 'CalMatters' 'CalWatchdog' 'Care 2' 'CBN'
#  'CBS News' 'Center - Major Media Sources' 'Center for Public Integrity'
#  'Centre View' 'Chicago Sun-Times' 'Chicago Tribune'
#  'Christian Science Monitor' 'City Journal' 'CNBC' 'CNET' 'CNN (Web News)'
#  'CNN - Editorial' 'CNS News' 'CNSNews.com' 'Columbia Journalism Review'
#  'Commentary Magazine' 'Conservative HQ' 'Cook Report' 'Countable'
#  'Counter Currents' 'Counterpointing' 'CrowdPAC' 'CU Independent'
# ...

# %%
data
# Out:
#      agree  agree_ratio   agreeance_text  \
# 0        3     1.500000  Somewhat Agrees
# 1    11421     1.370246  Somewhat Agrees
# 2     3371     0.649018        Disagrees
# 3     3162     2.577017  Strongly Agrees
# 4     2051     1.672920           Agrees
# ..     ...          ...              ...
# 273     37     1.370370  Somewhat Agrees
# 274    161     1.183824  Somewhat Agrees
# 275    405     2.515528  Strongly Agrees
# 276   1469     1.153061  Somewhat Agrees
# 277    331     2.068750  Strongly Agrees
#
#                                          allsides_page         bias  disagree  \
# 0    https://www.allsides.com/news-source/texas-obs...  left-center         2
# 1    https://www.allsides.com/news-source/abc-news-...  left-center      8335
# 2    https://www.allsides.com/news-source/al-jazeer...       center      5194
# 3      https://www.allsides.com/news-source/allsides-0     allsides      1227
# ...

# %%
bias_dictionary = {'left': -7, 'left-center': -3.5, 'center': 0, 'right-center': 3.5, 'right': 7}
data['Bias Rating'] = data['bias'].map(bias_dictionary)
data = data.dropna().reset_index()

# %%
data
# Out:
#      index  agree  agree_ratio   agreeance_text  \
# 0        0      3     1.500000  Somewhat Agrees
# 1        1  11421     1.370246  Somewhat Agrees
# 2        2   3371     0.649018        Disagrees
# 3        5   2129     2.940608  Strongly Agrees
# 4        6   5881     2.364696  Strongly Agrees
# ..     ...    ...          ...              ...
# 264    273     37     1.370370  Somewhat Agrees
# 265    274    161     1.183824  Somewhat Agrees
# 266    275    405     2.515528  Strongly Agrees
# 267    276   1469     1.153061  Somewhat Agrees
# 268    277    331     2.068750  Strongly Agrees
#
#                                          allsides_page         bias  disagree  \
# 0    https://www.allsides.com/news-source/texas-obs...  left-center         2
# 1    https://www.allsides.com/news-source/abc-news-...  left-center      8335
# 2    https://www.allsides.com/news-source/al-jazeer...       center      5194
# ...

# %%
data['name'].unique()
# Out:
# array(['The Texas Observer', 'ABC News', 'Al Jazeera', 'AlterNet',
#        'American Spectator', 'American Thinker', 'Aquinas College Saint',
#        'Arkansas Democrat-Gazette', 'Associated Press',
#        'Atlanta Journal-Constitution', 'Austin American-Statesman',
#        'Axios', 'Barnstable Patriot', 'BBC News', 'Bearing Drift',
#        'Bloomberg', 'Blue Virginia', 'Boing Boing', 'Boston Herald',
#        'Boston Herald Editorial', 'Bowling Green Daily News',
#        'Breitbart News', 'Business Insider', 'Bustle', 'BuzzFeed News',
#        'C-SPAN', 'CalMatters', 'CalWatchdog', 'Care 2', 'CBN', 'CBS News',
#        'Center - Major Media Sources', 'Center for Public Integrity',
#        'Centre View', 'Chicago Sun-Times', 'Chicago Tribune',
#        'Christian Science Monitor', 'City Journal', 'CNBC', 'CNET',
#        'CNN (Web News)', 'CNN - Editorial', 'CNS News', 'CNSNews.com',
#        'Columbia Journalism Review', 'Commentary Magazine',
# ...

# %%
final_data = pd.read_csv("../data/final_data.csv")

# %%
unique_sources = final_data[final_data['Source'].isin(data['name'].unique()) == False]['Source'].unique()
unique_sources
# Out:
# array(['ABC', 'Alternet', 'AP', 'Bipartisan Report', 'BBC', 'Breitbart',
#        'BuzzFeed', 'CBS', 'CNN', 'Crooks and Liars', 'CNSNews',
#        'Conservative Review', 'Counterpunch', 'Conservative Tribune',
#        'Daily Caller', 'Daily Signal', 'Daily Wire', 'EPI',
#        'Foreign Policy', 'Fortune', 'Forward', 'FreeSpeech TV', 'IJR',
#        'Huffington Post', 'Intercept', 'LA Times', 'Life News',
#        'Marketwatch', 'National Enquirer', 'National Public Radio',
#        'New York Times', 'NewsPunch', 'News and Guts', 'NewsMax',
#        'Occupy Democrats', 'Newsy', 'OZY', 'Palmer Report', 'Patribotics',
#        'PBS', 'Progressive, The', 'RedState', 'Second Nexus', 'ShareBlue',
#        'Talking Points Memo', 'The Advocate', 'The Blaze', 'The Skimm',
#        'Think Progress', 'Time', 'UrNews24', 'Truthout', 'Twitchy',
#        'USA Today', 'Wall Street Journal', 'Weather.com',
#        'World Truth TV', 'Wonkette', 'WorldNetDaily'], dtype=object)
