# %%
import numpy as np
import pandas as pd
import os

os.chdir("../")
from lib.scraper import scrape_body, scrape_header

from collections import Counter

# %%
df = pd.read_csv('data/Interactive Media Bias Chart - Ad Fontes Media.csv')
scraped_df = pd.read_csv('data/scraped_data.csv')

# %%
df.head()
# Out:
#   Source                                                Url   Bias  Quality
# 0    ABC  https://abcnews.go.com/Politics/us-disrupted-a...  -5.33    52.33
# 1    ABC  https://abcnews.go.com/Politics/appeals-court-...   0.67    51.67
# 2    ABC  https://abcnews.go.com/Politics/electoral-coll... -10.00    32.00
# 3    ABC  https://abcnews.go.com/Politics/facebook-agree...  -2.33    52.33
# 4    ABC  https://abcnews.go.com/Politics/donald-trump-t...  -4.33    52.67

# %%
scraped_df.head()
# Out:
#    Unnamed: 0 Source                                                Url  \
# 0           0    ABC  https://abcnews.go.com/Politics/us-disrupted-a...
# 1           1    ABC  https://abcnews.go.com/Politics/appeals-court-...
# 2           2    ABC  https://abcnews.go.com/Politics/electoral-coll...
# 3           3    ABC  https://abcnews.go.com/Politics/facebook-agree...
# 4           4    ABC  https://abcnews.go.com/Politics/donald-trump-t...
#
#     Bias  Quality                                             Header  \
# 0  -5.33    52.33  US disrupted alleged Russian trolls' internet ...
# 1   0.67    51.67  Appeals court says special counsel Robert Muel...
# 2 -10.00    32.00  The Electoral College limits the campaign play...
# 3  -2.33    52.33  Facebook agrees to hide demographics from land...
# 4  -4.33    52.67  Donald Trump and 'the Trump of the Tropics,' B...
#
#                                                 Body
# 0  U.S. cyber operators disrupted internet access...
# 1  A federal appeals court rejected the most dire...
# 2  U.S Senator Elizabeth Warren, who is competing...
# 3  Facebook announced Tuesday that it will block ...
# 4  President Donald Trump and "the Trump of the T...

# %% [markdown]
# ## Checking number of successful scrapes

# %%
clean_scraped = scraped_df.drop(scraped_df[scraped_df['Header'].isna()].index, axis=0)

# %%
len(clean_scraped)
# Out:
# 1311

# %%
len(scraped_df)
# Out:
# 1916

# %% [markdown]
# ## Checking content for scraped data

# %%
clean_scraped['header_len'] = clean_scraped['Header'].apply(lambda x: len(str(x)))
clean_scraped['body_len'] = clean_scraped['Body'].apply(lambda x: len(str(x)))

# %%
clean_scraped['header_len'].describe()
# Out:
# count    1311.000000
# mean       67.473684
# std        27.776052
# min         2.000000
# 25%        55.000000
# 50%        68.000000
# 75%        84.000000
# max       188.000000
# Name: header_len, dtype: float64

# %%
clean_scraped['body_len'].describe()
# Out:
# count      1311.000000
# mean       7185.812357
# std       17974.291546
# min           3.000000
# 25%        2607.500000
# 50%        4588.000000
# 75%        7159.500000
# max      380001.000000
# Name: body_len, dtype: float64

# %% [markdown]
# ## Checking sources where scraper did not work

# %%
failed_sources = scraped_df[scraped_df['Header'].isna()]['Source']

# %%
failed_sources.unique()
# Out:
# array(['Alternet', 'American Spectator, The', 'Axios',
#        'Bipartisan Report', 'CBS', 'CNN', 'Conservative Tribune',
#        'Counterpunch', 'Daily Beast', 'Daily Caller', 'Daily Kos',
#        'Daily Signal', 'Fortune', 'Fox News', 'FreeSpeech TV',
#        'Guacamoley', 'Huffington Post', 'InfoWars', 'Intercept',
#        'LA Times', 'Life News', 'MSNBC', 'NewsPunch', 'Occupy Democrats',
#        'One America News Network', 'Palmer Report', 'PJ Media',
#        'ProPublica', 'RedState', 'Reuters', 'Second Nexus', 'Spoutable',
#        'The Advocate', 'The American Conservative', 'The Economist',
#        'The Federalist', 'The Gateway Pundit', 'The Skimm', 'The Week',
#        'Time', 'Truthout', 'Twitchy', 'UrNews24', 'Washington Monthly',
#        'Washington Times', 'Weather.com', 'World Truth TV',
#        'WorldNetDaily'], dtype=object)

# %%
len(failed_sources)
# Out:
# 605

# %%
len(scraped_df['Source'].unique())
# Out:
# 108

# %%
sorted_source = {k: v for k, v in sorted(Counter(scraped_df['Source'].values).items(), key=lambda item: item[1])}
sorted_source
# Out:
# {'CNSNews': 1,
#  'EPI': 1,
#  'Spoutable': 1,
#  'Forward': 4,
#  'UrNews24': 5,
#  'Weather.com': 5,
#  'Occupy Democrats': 7,
#  'American Spectator, The': 9,
#  'Counterpunch': 9,
#  'Conservative Review': 10,
#  'Crooks and Liars': 10,
#  'FreeSpeech TV': 10,
#  'IJR': 10,
#  'Life News': 10,
#  'Newsy': 10,
#  'One America News Network': 10,
#  'Progressive, The': 10,
#  'Patribotics': 11,
#  'Daily Kos': 12,
#  'CBS': 13,
#  'Conservative Tribune': 13,
#  'Daily Beast': 13,
#  'Financial Times': 13,
#  'The Advocate': 13,
#  'The Nation': 13,
#  'Vanity Fair': 13,
#  'Wonkette': 13,
#  'World Truth TV': 13,
#  'Axios': 14,
#  'Breitbart': 14,
#  'Daily Mail': 14,
#  'Forbes': 14,
#  'Fortune': 14,
#  'Marketwatch': 14,
#  'National Review': 14,
#  'New York Post': 14,
#  'NewsMax': 14,
#  'RedState': 14,
#  'Slate': 14,
#  'The American Conservative': 14,
#  'The Atlantic': 14,
#  'The Economist': 14,
#  'The Federalist': 14,
#  'The Skimm': 14,
#  'Truthout': 14,
#  'Vox': 14,
#  'Al Jazeera': 15,
#  'BBC': 15,
#  'Bipartisan Report': 15,
#  'Business Insider': 15,
#  'BuzzFeed': 15,
#  'Daily Caller': 15,
#  'Daily Signal': 15,
#  'Daily Wire': 15,
#  'Democracy Now': 15,
#  'Fiscal Times': 15,
#  'Foreign Policy': 15,
#  'Guacamoley': 15,
#  'Huffington Post': 15,
#  'InfoWars': 15,
#  'Intercept': 15,
#  'Jacobin': 15,
#  'Mother Jones': 15,
#  'National Enquirer': 15,
#  'National Public Radio': 15,
#  'New Republic': 15,
#  'News and Guts': 15,
#  'NewsPunch': 15,
#  'PJ Media': 15,
#  'Politico': 15,
#  'ProPublica': 15,
#  'Quartz': 15,
#  'Reason': 15,
#  'Second Nexus': 15,
#  'ShareBlue': 15,
#  'Talking Points Memo': 15,
#  'The Blaze': 15,
#  'The Guardian': 15,
#  'The Hill': 15,
#  'The New Yorker': 15,
#  'Think Progress': 15,
#  'Time': 15,
#  'Vice': 15,
#  'Washington Monthly': 15,
#  'Washington Times': 15,
#  'WorldNetDaily': 15,
#  'Alternet': 16,
#  'OZY': 16,
#  'Palmer Report': 16,
#  'The Gateway Pundit': 16,
#  'Twitchy': 16,
#  'Washington Examiner': 16,
#  'Washington Free Beacon': 16,
#  'Christian Science Monitor': 17,
#  'PBS': 18,
#  'ABC': 20,
#  'The Week': 20,
#  'Bloomberg': 29,
#  'LA Times': 29,
#  'USA Today': 30,
#  'Reuters': 45,
#  'Wall Street Journal': 45,
#  'AP': 46,
#  'CNN': 54,
#  'Fox News': 71,
#  'MSNBC': 72,
#  'Washington Post': 89,
#  'New York Times': 105}

# %%
sorted_failed = {k: v for k, v in sorted(Counter(failed_sources).items(), key=lambda item: item[1])}
sorted_failed
# Out:
# {'CBS': 1,
#  'LA Times': 1,
#  'Reuters': 1,
#  'Second Nexus': 1,
#  'Spoutable': 1,
#  'Time': 3,
#  'The Economist': 4,
#  'The Skimm': 4,
#  'UrNews24': 5,
#  'Weather.com': 5,
#  'Occupy Democrats': 7,
#  'American Spectator, The': 9,
#  'Counterpunch': 9,
#  'FreeSpeech TV': 10,
#  'Life News': 10,
#  'One America News Network': 10,
#  'Daily Kos': 12,
#  'Conservative Tribune': 13,
#  'Daily Beast': 13,
#  'NewsPunch': 13,
#  'The Advocate': 13,
#  'World Truth TV': 13,
#  'Axios': 14,
#  'Fortune': 14,
#  'RedState': 14,
#  'The American Conservative': 14,
#  'The Federalist': 14,
#  'Truthout': 14,
#  'Bipartisan Report': 15,
#  'Daily Caller': 15,
#  'Daily Signal': 15,
#  'Guacamoley': 15,
#  'Huffington Post': 15,
#  'InfoWars': 15,
#  'Intercept': 15,
#  'PJ Media': 15,
#  'ProPublica': 15,
#  'Washington Monthly': 15,
#  'Washington Times': 15,
#  'WorldNetDaily': 15,
#  'Alternet': 16,
#  'Palmer Report': 16,
#  'The Gateway Pundit': 16,
#  'Twitchy': 16,
#  'The Week': 20,
#  'CNN': 25,
#  'MSNBC': 33,
#  'Fox News': 41}

# %%
source_df = pd.DataFrame(sorted_source.items(), columns=['Source', 'Count'])
failed_df = pd.DataFrame(sorted_failed.items(), columns=['Source', 'Failed'])

# %%
failed_df.head()
# Out:
#          Source  Failed
# 0           CBS       1
# 1      LA Times       1
# 2       Reuters       1
# 3  Second Nexus       1
# 4     Spoutable       1

# %%
compare_df = source_df.merge(failed_df, on='Source', how='left')
compare_df.head()
# Out:
#       Source  Count  Failed
# 0    CNSNews      1     NaN
# 1        EPI      1     NaN
# 2  Spoutable      1     1.0
# 3    Forward      4     NaN
# 4   UrNews24      5     5.0

# %%
compare_df[compare_df['Failed'].notnull()]
# Out:
#                         Source  Count  Failed
# 2                    Spoutable      1     1.0
# 4                     UrNews24      5     5.0
# 5                  Weather.com      5     5.0
# 6             Occupy Democrats      7     7.0
# 7      American Spectator, The      9     9.0
# 8                 Counterpunch      9     9.0
# 11               FreeSpeech TV     10    10.0
# 13                   Life News     10    10.0
# 15    One America News Network     10    10.0
# 18                   Daily Kos     12    12.0
# 19                         CBS     13     1.0
# 20        Conservative Tribune     13    13.0
# 21                 Daily Beast     13    13.0
# 23                The Advocate     13    13.0
# 27              World Truth TV     13    13.0
# 28                       Axios     14    14.0
# 32                     Fortune     14    14.0
# 37                    RedState     14    14.0
# 39   The American Conservative     14    14.0
# 41               The Economist     14     4.0
# 42              The Federalist     14    14.0
# 43                   The Skimm     14     4.0
# 44                    Truthout     14    14.0
# 48           Bipartisan Report     15    15.0
# 51                Daily Caller     15    15.0
# 52                Daily Signal     15    15.0
# 57                  Guacamoley     15    15.0
# 58             Huffington Post     15    15.0
# 59                    InfoWars     15    15.0
# 60                   Intercept     15    15.0
# 67                   NewsPunch     15    13.0
# 68                    PJ Media     15    15.0
# 70                  ProPublica     15    15.0
# 73                Second Nexus     15     1.0
# 81                        Time     15     3.0
# 83          Washington Monthly     15    15.0
# 84            Washington Times     15    15.0
# 85               WorldNetDaily     15    15.0
# 86                    Alternet     16    16.0
# 88               Palmer Report     16    16.0
# 89          The Gateway Pundit     16    16.0
# 90                     Twitchy     16    16.0
# 96                    The Week     20    20.0
# 98                    LA Times     29     1.0
# 100                    Reuters     45     1.0
# 103                        CNN     54    25.0
# 104                   Fox News     71    41.0
# 105                      MSNBC     72    33.0

# %%
df[df['Source'] == 'Alternet']['Url']
# Out:
# 35    https://www.alternet.org/2019/02/top-gop-leade...
# 36    https://www.alternet.org/2019/03/heres-what-re...
# 37    https://www.alternet.org/2019/03/white-nationa...
# 38    https://www.alternet.org/2019/04/house-republi...
# 39    https://www.alternet.org/2019/02/conservative-...
# 40    https://www.alternet.org/2019/02/ex-lawyer-for...
# 41    https://www.alternet.org/2018/09/michael-moore...
# 42    https://www.alternet.org/2019/01/evangelical-c...
# 43    https://www.alternet.org/2019/02/heres-how-muc...
# 44    https://www.alternet.org/2019/03/trump-has-sol...
# 45    https://www.alternet.org/2019/03/mueller-just-...
# 46    https://www.alternet.org/2019/03/this-needs-to...
# 47    https://www.alternet.org/2019/04/now-trump-thi...
# 48    https://www.alternet.org/2019/04/he-is-going-t...
# 49    https://www.alternet.org/2019/04/a-cognitive-s...
# 50    https://www.alternet.org/2019/04/trump-lashes-...
# Name: Url, dtype: object

# %%
clean_scraped[clean_scraped['header_len'] == clean_scraped['header_len'].min()]
# Out:
#       Unnamed: 0   Source                                                Url  \
# 1024        1024  NewsMax  https://www.newsmax.com/world/globaltalk/jared...
# 1026        1026  NewsMax  https://www.newsmax.com/world/globaltalk/trump...
# 1033        1033  NewsMax  https://www.newsmax.com/finance/peter-morici/t...
#
#        Bias  Quality Header  \
# 1024  10.67    52.33   \n\n
# 1026   5.50    50.50   \n\n
# 1033  13.75    26.75   \n\n
#
#                                                    Body  header_len  body_len
# 1024   Tuesday, 26 February 2019 06:38 AM In an inte...           2      4112
# 1026   JONATHAN LEMIRE\nTuesday, 26 February 2019 05...           2      8118
# 1033   .authImage{float:left;margin-right:10px;heigh...           2      5740

# %%
clean_scraped[clean_scraped['Source'] == 'NewsMax']
# Out:
#       Unnamed: 0   Source                                                Url  \
# 1024        1024  NewsMax  https://www.newsmax.com/world/globaltalk/jared...
# 1025        1025  NewsMax  https://www.newsmax.com/headline/border-wall-e...
# 1026        1026  NewsMax  https://www.newsmax.com/world/globaltalk/trump...
# 1027        1027  NewsMax  https://www.newsmax.com/john-gizzi/trump-kim-v...
# 1028        1028  NewsMax  https://www.newsmax.com/george-j-marlin/new-yo...
# 1029        1029  NewsMax  https://www.newsmax.com/headline/trump-social-...
# 1030        1030  NewsMax  https://www.newsmax.com/newsfront/donaldtrumpj...
# 1031        1031  NewsMax  https://www.newsmax.com/streettalk/murdoch-fox...
# 1032        1032  NewsMax  https://www.newsmax.com/us/ralph-peters-john-m...
# 1033        1033  NewsMax  https://www.newsmax.com/finance/peter-morici/t...
# 1034        1034  NewsMax  https://www.newsmax.com/newsfront/us-trump-imm...
# 13          13    ABC  https://abcnews.go.com/Politics/trump-blasts-m...
# 14          14    ABC  https://abcnews.go.com/US/deferred-prosecution...
# 15          15    ABC  https://abcnews.go.com/Politics/trump-vetoes-r...
# 16          16    ABC  https://abcnews.go.com/Politics/takeaways-1st-...
# 17          17    ABC  https://abcnews.go.com/US/states-attorney-kim-...
# 18          18    ABC  https://abcnews.go.com/Politics/attorney-gener...
# 19          19    ABC  https://abcnews.go.com/US/search-underway-fort...
#
#      Bias  Quality                                             Header  \
# 0   -5.33    52.33  US disrupted alleged Russian trolls' internet ...
# 1    0.67    51.67  Appeals court says special counsel Robert Muel...
# 2  -10.00    32.00  The Electoral College limits the campaign play...
# 3   -2.33    52.33  Facebook agrees to hide demographics from land...
# 4   -4.33    52.67  Donald Trump and 'the Trump of the Tropics,' B...
# 5    0.67    51.00  New body cam video shows deadly North Carolina...
# 6    0.00    49.33  Michigan AG to review 2015 fatal shooting by I...
# 7   -2.33    54.33  As Mueller report release nears, White House p...
# 8    1.67    49.00  Abortion rights group asks Supreme Court to st...
# 9   -6.00    52.00  As Trump attacks Omar, progressive Democrats u...
# 10  -0.67    47.67  What we've learned from 2020 candidates' tax r...
# 11   3.50    56.75  Michael Cohen, President Trump’s former person...
# 12  -0.75    53.25  Republican at center of North Carolina electio...
# 13 -12.25    50.75  President Trump again blasts John McCain, says...
# 14   0.50    50.00  Plea deal offered to New England Patriots owne...
# 15   9.75    48.00  Trump vetoes resolution to end US involvement ...
# 16  -6.50    46.75  5 takeaways from the 1st major fundraising rep...
# 17  -1.00    50.00  State's Attorney Kim Foxx calls Jussie Smollet...
# 18  -2.75    43.50  Attorney general orders some asylum seekers to...
# 19   0.56    54.00                                       \nSections\n
#
#                                                  Body  header_len  body_len
# 0   U.S. cyber operators disrupted internet access...          76      3967
# 1   A federal appeals court rejected the most dire...         104      3777
# 2   U.S Senator Elizabeth Warren, who is competing...          92      5349
# 3   Facebook announced Tuesday that it will block ...          83      3187
# 4   President Donald Trump and "the Trump of the T...          89      7120
# 5   Newly-released body camera footage reveals the...          77      3670
# 6   DETROIT -- \nMichigan's attorney general will ...          54       843
# 7   While President Donald Trump and the White Hou...          78      3069
# 8   Abortion rights advocates have asked the U.S. ...          85      3131
# 9   Even as President Donald Trump continues his f...          76      6799
# 10  A handful of Democratic candidates for preside...          52      8648
# 11  Michael Cohen has been officially disbarred in...         100      1125
# 12  Mark Harris, the Republican candidate in North...          90      2346
# 13  President Donald Trump again criticized the la...          87      1574
# 14  Robert Kraft, the owner of the Super Bowl cham...          97      6582
# 15  President Donald Trump has vetoed a resolution...          54      3854
# 16  Presidential candidates submitted their first ...          80      9236
# 17  Cook County State's Attorney Kim Foxx referred...         108      4383
# 18  As part of the Trump administration's effort t...          67      3488
# 19  A Fort Carson soldier, missing since Monday ni...          10      1916

# %%
unscraped_url = scraped_df[scraped_df['Header'].isna()]['Url']

# %% [markdown]
# ### Checking Errors

# %%
body_errors = []
head_errors = []

for url in unscraped_url:
    body_errors.append(scrape_body(url))
    head_errors.append(scrape_header(url))
# Out:
# 35      https://www.alternet.org/2019/02/top-gop-leade...
# 36      https://www.alternet.org/2019/03/heres-what-re...
# 37      https://www.alternet.org/2019/03/white-nationa...
