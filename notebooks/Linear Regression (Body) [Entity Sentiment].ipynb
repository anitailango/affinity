# %% [markdown]
# ## Importing Libraries

# %%
# Data Analysis and Processing
import numpy as np
import pandas as pd
from collections import Counter

# Natural Language Processing
### General
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
import string

### Sentiment Analysis
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

### Part of Speech Tagging
import spacy
nlp = spacy.load('en_core_web_sm')

# Modelling
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Evaluation
from scipy import stats
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Function Definitions

# %%
def get_sentiment(text):
    # gets the compound score of the sentiment using the VADER lexicon
    sid = SentimentIntensityAnalyzer()
    
    results = sid.polarity_scores(text)
    sentiment = results['compound']
    return sentiment

# %%
def get_entities(text):
    # gets the entities from the sentence and returns a list of them
    doc = nlp(text)
    return list(doc.ents)

# %%
def extract_sentences(word, text):
    # extract all sentences in text in which word appears
    sentences = []
    for sentence in text.split('.'):
        if (word in sentence):
            sentences.append(sentence)
    
    return sentences

# %%
def extract_get_sentiment(word, text):
    # returns aggregate of sentiment for all sentences that contains word in text
    text = text.lower()
    word = word.lower()
    
    sentiment = get_sentiment('.'.join(extract_sentences(word, text)))
    return sentiment

# %% [markdown]
# ## NLP Use Example

# %%
sentence = 'Trump is a horrible president, Trump, Bernie Sanders are equally bad'

# %%
get_sentiment(sentence)
# Out:
# -0.7906

# %%
get_entities(sentence)
# Out:
# [Trump, Trump, Bernie Sanders]

# %%
extract_sentences('one', 'hello one who. There one')
# Out:
# ['hello one who', ' There one']

# %% [markdown]
# ## Importing Data

# %%
#df = pd.read_csv("../data/final_data.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
body_df = df.drop(columns=['Url', 'Author', 'Date', 'Header', 'Source', 'n_links', 'Quality'])

# %%
body_df.head()
# Out:
#                                                 Body   Bias
# 0  Abortion rights advocates have asked the U.S. ...   1.67
# 1  A federal appeals court rejected the most dire...   0.67
# 2  As part of the Trump administration's effort t...  -2.75
# 3  President Donald Trump and "the Trump of the T...  -4.33
# 4  U.S Senator Elizabeth Warren, who is competing... -10.00

# %%
def process_text(text):
    # 1. Lowercase text
    # 2. Removes punctuation
    # 3. Removes stopwords
    # 4. Lemmatizes remaining words

    text = text.lower()
    
    # removes punctuation
    nopunc_digit = [char for char in text if char not in string.punctuation and not char.isdigit()]
    nopunc_digit = ''.join(nopunc_digit)
    
    # removes stopwords and lemmatizes remaining words
    wnl = WordNetLemmatizer()
    lemmatized = [wnl.lemmatize(word) for word in nopunc_digit.split() if not wnl.lemmatize(word) in set(stopwords.words('english'))]
    lemmatized = ' '.join(lemmatized)
    
    return lemmatized

# %%
body_df['cleaned_body'] = body_df['Body'].apply(lambda x: process_text(x))

# %% [markdown]
# ## Saving processed df

# %%
#body_df.to_csv('preprocess1.csv')

# %% [markdown]
# ## Loading processed df

# %%
body_df = pd.read_csv('preprocess1.csv')

# %% [markdown]
# ## Extracting Entities

# %%
all_body = body_df['cleaned_body']

# %%
all_entities = []
for text in all_body:
    ents = get_entities(text)
    all_entities.append(ents)

# %%
flat_entities = [str(item) for sublist in all_entities for item in sublist]

# %%
ents_dict = Counter(flat_entities)
sorted_ents = {k: v for k, v in sorted(ents_dict.items(), reverse=True, key=lambda item: item[1])}

# %%
sorted_ents
# Out:
# {'one': 2111,
#  'american': 1256,
#  'trump': 1182,
#  'two': 1158,
#  'republican': 1127,
#  'democrat': 1093,
#  'first': 1006,
#  'cohen': 965,
#  'tuesday': 951,
#  'congress': 925,
#  'russian': 708,
#  'new york': 634,
#  'white house': 587,
#  'russia': 584,
#  'donald trump': 553,
#  'democratic': 528,
#  'today': 503,
#  'united state': 491,
#  'senate': 458,
#  'million': 440,
#  'doe': 436,
#  'last year': 435,
#  'three': 422,
#  'washington': 419,
#  'america': 413,
#  'second': 400,
#  'monday': 398,
#  'fbi': 383,
#  'china': 382,
#  'wednesday': 343,
#  'north korea': 330,
#  'year': 323,
#  'last week': 316,
#  'house': 275,
#  'muslim': 262,
#  'february': 258,
#  'new zealand': 257,
#  'california': 255,
#  'april': 254,
#  'kim': 233,
#  'u': 225,
#  'cnn': 216,
#  'barr': 215,
#  'four': 205,
#  'thursday': 204,
#  'gop': 204,
#  'march': 203,
#  'chinese': 202,
#  'clinton': 201,
#  'florida': 195,
#  'fox news': 188,
#  'january': 187,
#  'venezuela': 182,
#  'michael cohen': 182,
#  'israel': 169,
#  'moscow': 163,
#  'hillary clinton': 162,
#  'yemen': 162,
#  'iran': 162,
#  'north korean': 162,
#  'supreme court': 160,
#  'boeing': 159,
#  'third': 158,
#  'last month': 158,
#  'french': 153,
#  'december': 150,
#  'texas': 142,
#  'justice department': 142,
#  'france': 140,
#  'five': 139,
#  'omar': 139,
#  'amy goodman': 138,
#  'friday': 137,
#  'week': 136,
#  'june': 133,
#  'vietnam': 131,
#  'daily': 131,
#  'dozen': 130,
#  'billion': 130,
#  'robert mueller': 129,
#  'jewish': 127,
#  'eu': 124,
#  'britain': 124,
#  'morning': 123,
#  'uk': 123,
#  'european': 123,
#  'cuba': 122,
#  'october': 121,
#  'november': 121,
#  'venezuelan': 121,
#  'saudi': 121,
#  'wa': 120,
#  'british': 119,
#  'hundred': 118,
#  'month': 118,
#  'chicago': 117,
#  'warren': 116,
#  'europe': 116,
#  'north carolina': 115,
#  'thousand': 113,
#  'brazil': 110,
#  'saudi arabia': 110,
#  'christian': 110,
#  'iraq': 110,
#  'yesterday': 109,
#  'india': 108,
#  'washington post': 105,
#  'faa': 105,
#  'half': 104,
#  'sunday': 104,
#  'cia': 100,
#  'harris': 100,
#  'iowa': 100,
#  'fed': 99,
#  'six': 98,
#  'kim jong un': 97,
#  'august': 97,
#  'indian': 96,
#  'earlier month': 96,
#  'new york city': 96,
#  'pakistan': 94,
#  'london': 92,
#  'lawmaker': 91,
#  'hour': 89,
#  'medicare': 89,
#  'afghanistan': 89,
#  'july': 89,
#  'mexico': 88,
#  'two year': 88,
#  'mueller': 87,
#  'maryland': 86,
#  'alexandria': 86,
#  'kraft': 86,
#  'manhattan': 84,
#  'los angeles': 84,
#  'syria': 84,
#  'new jersey': 83,
#  'night': 83,
#  'day': 81,
#  'paris': 79,
#  'elizabeth warren': 78,
#  'september': 78,
#  'israeli': 78,
#  'recent year': 76,
#  'hanoi': 75,
#  'johnson': 75,
#  'annual': 74,
#  'pentagon': 74,
#  'japan': 74,
#  'notre dame': 74,
#  'zero': 71,
#  'seven': 70,
#  'evening': 70,
#  'navy': 70,
#  'nra': 69,
#  'palestinian': 69,
#  'massachusetts': 68,
#  'english': 66,
#  'eight': 66,
#  'islamic': 66,
#  'ohio': 64,
#  'deutsche bank': 64,
#  'capitol hill': 64,
#  'three year': 63,
#  'nbc news': 63,
#  'virginia': 62,
#  'putin': 62,
#  'democratic party': 61,
#  'wall street journal': 61,
#  'brexit': 61,
#  'year ago': 59,
#  'european union': 59,
#  'australia': 59,
#  'colorado': 58,
#  'cuban': 58,
#  'san francisco': 58,
#  'amazon': 58,
#  'maduro': 57,
#  'korean': 57,
#  'saturday': 57,
#  'max': 57,
#  'next year': 57,
#  'fox': 57,
#  'kamala harris': 56,
#  'ukraine': 56,
#  'brazilian': 55,
#  'yearold': 55,
#  'kushner': 55,
#  'pennsylvania': 54,
#  'donald': 54,
#  'minnesota': 53,
#  'democrats': 53,
#  'le': 52,
#  'south korea': 52,
#  'treasury': 52,
#  'nancy pelosi': 51,
#  'marijuana': 51,
#  'winter': 50,
#  'tennessee': 50,
#  'william barr': 49,
#  'ilhan omar': 49,
#  'john mccain': 49,
#  'australian': 49,
#  'mexican': 49,
#  'iranian': 49,
#  'apple': 49,
#  'south carolina': 49,
#  'hollywood': 48,
#  'german': 48,
#  'irs': 47,
#  'five year': 47,
#  'castro': 47,
#  'obama': 47,
#  'afternoon': 47,
#  'indiana': 46,
#  'ten thousand': 46,
#  'germany': 46,
#  'yanukovych': 46,
#  'williams': 45,
#  'singapore': 45,
#  'decade': 45,
#  'miller': 44,
#  'vladimir putin': 44,
#  'arizona': 44,
#  'joe biden': 43,
#  'pete buttigieg': 43,
#  'pyongyang': 43,
#  'nine': 43,
#  'ukrainian': 43,
#  'beto': 43,
#  'bush': 43,
#  'isi': 43,
#  'fda': 43,
#  'conway': 43,
#  'flynn': 43,
#  'mike pompeo': 42,
#  'jordan': 42,
#  'past year': 42,
#  'associated press': 42,
#  'west virginia': 42,
#  'south korean': 41,
#  'senate intelligence committee': 41,
#  'matt gaetz': 41,
#  'notre': 41,
#  'summer': 41,
#  'wohl': 41,
#  'longterm': 40,
#  'pakistani': 39,
#  'beijing': 39,
#  'jew': 39,
#  'barack obama': 38,
#  'michigan': 38,
#  'catholic': 38,
#  'million dollar': 38,
#  'one day': 38,
#  'tonight': 38,
#  'msnbc': 38,
#  'three day': 37,
#  'missouri': 37,
#  'turkey': 37,
#  'graham': 37,
#  'roger stone': 36,
#  'nebraska': 36,
#  'bill clinton': 36,
#  'georgia': 36,
#  'state department': 36,
#  'cohens': 36,
#  'african': 36,
#  'new hampshire': 36,
#  'george w bush': 36,
#  'maine': 35,
#  'monday night': 35,
#  'cohen wa': 35,
#  'kashmir': 35,
#  'illinois': 34,
#  'tower moscow': 34,
#  'united states': 34,
#  'japanese': 34,
#  'sudan': 34,
#  'singlepayer': 34,
#  'ftc': 34,
#  'smollett': 33,
#  'arab': 33,
#  'middle east': 33,
#  'gonzalez carranza': 33,
#  'denver': 33,
#  'asian': 33,
#  'qualcomm': 33,
#  'canada': 32,
#  'paul manafort': 32,
#  'world war ii': 32,
#  'kremlin': 32,
#  'mike penny': 32,
#  'african american': 32,
#  'reuters': 32,
#  'fourth': 32,
#  'last summer': 32,
#  'sec': 32,
#  'norway': 32,
#  'kentucky': 31,
#  'mosque': 31,
#  'minute': 31,
#  'two decade': 31,
#  'medicaid': 31,
#  'jacinda ardern': 31,
#  'somalia': 31,
#  'norwegian': 31,
#  'silicon valley': 31,
#  'iraqi': 31,
#  'louisiana': 30,
#  'abc news': 30,
#  'republican party': 30,
#  'nearly million': 30,
#  'michael flynn': 30,
#  'every day': 30,
#  'nbc': 30,
#  'intel': 30,
#  'mulvaney': 30,
#  'last night': 30,
#  'us': 29,
#  'vermont': 29,
#  'donald j trump': 29,
#  'army': 29,
#  'southern district': 29,
#  'indonesia': 29,
#  'mcconnell': 29,
#  'next day': 29,
#  'tomorrow': 29,
#  'wikileaks': 29,
#  'weekend': 29,
#  'wojcicki': 29,
#  'u department': 28,
#  'monthly': 28,
#  'connecticut': 28,
#  'fifth': 28,
#  'macron': 28,
#  'julian': 28,
#  'nazi': 28,
#  'bernie': 28,
#  'fixer': 27,
#  'two day': 27,
#  'next week': 27,
#  'oregon': 27,
#  'hundred thousand': 27,
#  'next month': 27,
#  'africa': 27,
#  'pell': 27,
#  'gonzalez': 27,
#  'earlier year': 27,
#  'bernie sander': 27,
#  'wisconsin': 27,
#  'pecker': 27,
#  'first quarter': 26,
#  'midwest': 26,
#  'south dakota': 26,
#  'yemeni': 26,
#  'boston': 26,
#  'canadian': 26,
#  'ethiopian': 26,
#  'brooklyn': 26,
#  'white supremacist': 26,
#  'democratic national committee': 26,
#  'recent week': 25,
#  'yang': 25,
#  'jim jordan': 25,
#  'vietnamese': 25,
#  'un': 25,
#  'later year': 25,
#  'four year': 25,
#  'asia': 25,
#  'wolf': 25,
#  'klobuchar': 24,
#  'alaska': 24,
#  'united kingdom': 24,
#  'colombia': 24,
#  'miami': 24,
#  'egypt': 24,
#  'mitch mcconnell': 24,
#  'instagram': 24,
#  'vatican': 24,
#  'quarterly': 24,
#  'morgan stanley': 24,
#  'muthana': 24,
#  'microsoft': 24,
#  'kohl': 24,
#  'jupiter': 23,
#  'jared kushner': 23,
#  'alabama': 23,
#  'peru': 23,
#  'breyer': 23,
#  'nevada': 23,
#  'district columbia': 23,
#  'swedish': 23,
#  'six month': 23,
#  'earth': 23,
#  'first day': 23,
#  'oakland': 23,
#  'algorithm': 23,
#  'pais': 23,
#  'jeff session': 22,
#  'nato': 22,
#  'bolsonaro': 22,
#  'susan collins': 22,
#  'fiscal year': 22,
#  'two year ago': 22,
#  'trump wa': 22,
#  'americans': 22,
#  'hhs': 22,
#  'last two year': 22,
#  'garcia': 22,
#  'cbs news': 22,
#  'warner': 22,
#  'mississippi': 22,
#  'netanyahu': 22,
#  'usa today': 22,
#  'islam': 22,
#  'bayoumi': 22,
#  'de blasio': 22,
#  'robert muellers': 21,
#  'american civil liberty union': 21,
#  'house judiciary committee': 21,
#  'james comey': 21,
#  'dems': 21,
#  'late last year': 21,
#  'two month': 21,
#  'italian': 21,
#  'weekly': 21,
#  'qatar': 21,
#  'juan gonzález': 21,
#  'two week': 21,
#  'three month': 20,
#  'barrs': 20,
#  'social medium': 20,
#  'every week': 20,
#  'spain': 20,
#  'jr': 20,
#  'hispanic': 20,
#  'authoritarian': 20,
#  'rudy giuliani': 20,
#  'carlson': 20,
#  'smith': 20,
#  'utah': 20,
#  'houston': 20,
#  'bos': 20,
#  'kazakhstan': 20,
#  'gallup': 20,
#  'berlin': 20,
#  'george conway': 20,
#  'jefferson county': 20,
#  'martin county': 20,
#  'nasa': 20,
#  'zinke': 20,
#  'last november': 19,
#  'united nation': 19,
#  'palm beach county': 19,
#  'moon': 19,
#  'lisa murkowski': 19,
#  'communist': 19,
#  'turkish': 19,
#  'xi jinping': 19,
#  'pm': 19,
#  'homeland security': 19,
#  'lindsey graham': 19,
#  'nigerian': 19,
#  'mcgahn': 19,
#  'martin': 19,
#  'new mexico': 19,
#  'baltimore': 19,
#  'sanctuary city': 19,
#  'ted cruz': 19,
#  'matthew': 19,
#  'matt': 19,
#  'atlantic': 19,
#  'jair bolsonaro': 18,
#  'sarah sander': 18,
#  'africanamerican': 18,
#  'google': 18,
#  'moon jaein': 18,
#  'billion dollar': 18,
#  'nearly percent': 18,
#  'indonesian': 18,
#  'amy': 18,
#  'ethiopia': 18,
#  'emmanuel macron': 18,
#  'past decade': 18,
#  'north dakota': 18,
#  'brussels': 18,
#  'kramer': 18,
#  'marco rubio': 18,
#  'stephen miller': 18,
#  'soviet union': 18,
#  'bitcoin': 18,
#  'neonazis': 18,
#  'ecuador': 18,
#  'sweden': 18,
#  'seattle': 18,
#  'kelly': 18,
#  'rod rosenstein': 17,
#  'latin america': 17,
#  'mark harris': 17,
#  'jamal khashoggi': 17,
#  'recent day': 17,
#  's': 17,
#  'united arab': 17,
#  'six year': 17,
#  'several year': 17,
#  'mark meadow': 17,
#  'healthcare': 17,
#  'u court': 17,
#  'lighthizer': 17,
#  'tucker carlson': 17,
#  'epa': 17,
#  'native american': 17,
#  'colombian': 17,
#  'last fall': 17,
#  'kagan': 17,
#  'thomas': 17,
#  'giuliani': 17,
#  'harvard': 17,
#  'steese': 17,
#  'moynihan': 17,
#  'u military': 16,
#  'annually': 16,
#  'eight year': 16,
#  'recent month': 16,
#  'central american': 16,
#  'ten': 16,
#  'hundred million dollar': 16,
#  'lee': 16,
#  'rome': 16,
#  'brett kavanaugh': 16,
#  'election day': 16,
#  'juan guaidó': 16,
#  'jerusalem': 16,
#  'lebanon': 16,
#  'bill de blasio': 16,
#  'lesbian': 16,
#  'michael sanchez': 16,
#  'donald trump jr': 16,
#  'phillips': 16,
#  'newton': 16,
#  'puerto rico': 16,
#  'propublica': 16,
#  'u supreme court': 15,
#  'southern': 15,
#  'month year': 15,
#  'national security': 15,
#  'last august': 15,
#  'christopher steele': 15,
#  'coming week': 15,
#  'pompeo': 15,
#  'lanny davis': 15,
#  'u district': 15,
#  'interior': 15,
#  'amy klobuchar': 15,
#  'buzzfeed news': 15,
#  'five day': 15,
#  'la vega': 15,
#  'control house': 15,
#  'george papadopoulos': 15,
#  'bronx': 15,
#  'stanford': 15,
#  'penny': 15,
#  'kellyanne conway': 15,
#  'jim crow': 15,
#  'little month': 15,
#  'irish': 15,
#  'one year': 14,
#  'nfl': 14,
#  'house intelligence committee': 14,
#  'madrid': 14,
#  'western': 14,
#  'bbc': 14,
#  'tuesday night': 14,
#  'journal': 14,
#  'alito': 14,
#  'hernandez': 14,
#  'every morning': 14,
#  'app': 14,
#  'airbus': 14,
#  'poland': 14,
#  'philadelphia': 14,
#  'rosenstein': 14,
#  'benjamin netanyahu': 14,
#  'quarter': 14,
#  'daily caller news foundation': 14,
#  'dnc': 14,
#  'central america': 14,
#  'el paso': 14,
#  'scotland': 14,
#  'reagan': 14,
#  'jane': 14,
#  'nearly year': 14,
#  'syrian': 14,
#  'first year': 14,
#  'year later': 14,
#  'united methodist church': 14,
#  'feinstein': 14,
#  'scandinavian': 14,
#  'noise daily news': 14,
#  'analyse': 14,
#  'krueger': 14,
#  'jacob wohl': 14,
#  'elise stefanik': 14,
#  'chuck schumer': 13,
#  'mohammed bin salman': 13,
#  'antimuslim': 13,
#  'trump administration': 13,
#  'john bolton': 13,
#  'washington dc': 13,
#  'rick gate': 13,
#  'aaron': 13,
#  'egyptian': 13,
#  'philippine': 13,
#  'bolton': 13,
#  'n’t': 13,
#  'kim jongun': 13,
#  'parliament': 13,
#  'past month': 13,
#  'gaetz': 13,
#  'cummings': 13,
#  'th circuit': 13,
#  'fifty': 13,
#  'sixth': 13,
#  'new yorkers': 13,
#  'italy': 13,
#  'mccain': 13,
#  'spanish': 13,
#  'west bank': 13,
#  'bill': 13,
#  'two dozen': 13,
#  'tommy robinson': 13,
#  'al qaeda': 13,
#  'next decade': 13,
#  'national assembly': 13,
#  'libya': 13,
#  'new york city’s': 13,
#  'ronald reagan': 13,
#  'solidarity': 13,
#  'andy campbell': 13,
#  'powell': 13,
#  'william brangham': 13,
#  'jay inslee': 12,
#  'million year': 12,
#  'richard nixon': 12,
#  'asia day': 12,
#  'korea': 12,
#  'wyden': 12,
#  'steven mnuchin': 12,
#  'almost year': 12,
#  'calif': 12,
#  'samuel alito': 12,
#  'stephen breyer': 12,
#  'ibm': 12,
#  'davis': 12,
#  'seven year': 12,
#  'buzzfeed': 12,
#  'abc': 12,
#  'playboy': 12,
#  'guy': 12,
#  'republicans': 12,
#  'guardian': 12,
#  'decade ago': 12,
#  'federal reserve': 12,
#  'serbia': 12,
#  'north america': 12,
#  'nearly half': 12,
#  'meadow': 12,
#  'anderson': 12,
#  'kaji': 12,
#  'three decade': 12,
#  'kennedy': 12,
#  'ryan': 12,
#  'dea': 12,
#  'va': 12,
#  'threeday': 11,
#  'u house': 11,
#  'tuesday afternoon': 11,
#  'one two': 11,
#  'islamophobic': 11,
#  'robert kraft': 11,
#  'detroit': 11,
#  'seoul': 11,
#  'brenton tarrant': 11,
#  'latin american': 11,
#  'four month': 11,
#  'end day': 11,
#  'ag': 11,
#  'hanoi vietnam': 11,
#  'two hour': 11,
#  'tokyo': 11,
#  'steve bannon': 11,
#  'last june': 11,
#  'nine month': 11,
#  'toledo': 11,
#  'wendy williams': 11,
#  'ali': 11,
#  'last decade': 11,
#  'gao': 11,
#  'south africa': 11,
#  'jeff bezos': 11,
#  'earlier tuesday': 11,
#  'digital': 11,
#  'defense': 11,
#  'bill barr': 11,
#  'century': 11,
#  'stormy daniel': 11,
#  'every year': 11,
#  'trillion': 11,
#  'ford': 11,
#  'new yorker': 11,
#  'last friday': 11,
#  'cleveland': 11,
#  'meghan mccain': 11,
#  'paul ryan': 11,
#  'dallas': 11,
#  'u troop': 11,
#  'th century': 11,
#  'highpoverty school': 11,
#  'tehran': 11,
#  'prorussian': 11,
#  'booker': 11,
#  'thirteen': 11,
#  'bill wa': 11,
#  'orange county': 11,
#  'eastern': 11,
#  'idaho': 11,
#  'opec': 11,
#  'le percent': 10,
#  'mitt romney': 10,
#  'hawaii': 10,
#  'switzerland': 10,
#  'last october': 10,
#  'hillary': 10,
#  'hamburg': 10,
#  'catholic church': 10,
#  'justin': 10,
#  'roughly million': 10,
#  'joaquin castro': 10,
#  'one four': 10,
#  'biden': 10,
#  'charleston': 10,
#  'al noor mosque': 10,
#  'sarah huckabee': 10,
#  'martha': 10,
#  'three year ago': 10,
#  'half million': 10,
#  'ten year': 10,
#  'ed': 10,
#  'theresa': 10,
#  'usa': 10,
#  'pittsburgh': 10,
#  'earlier week': 10,
#  'nixon': 10,
#  'bethlehem': 10,
#  'eric swalwell': 10,
#  'rico': 10,
#  'ben shapiro': 10,
#  'watergate': 10,
#  'pelosi': 10,
#  'afghan': 10,
#  'hbo': 10,
#  'dan crenshaw': 10,
#  'libertarian': 10,
#  'monsanto': 10,
#  'central bank': 10,
#  'san diego': 10,
#  'briggs': 10,
#  'two year later': 10,
#  'carter': 10,
#  'likud': 10,
#  'baghdad': 10,
#  'howard lorber': 10,
#  'shen yun': 10,
#  'zhou': 10,
#  'million million': 9,
#  'one million': 9,
#  'meghan': 9,
#  'nancy pelosi dcalif': 9,
#  'cook county': 9,
#  'five year ago': 9,
#  'social security': 9,
#  'elijah cummings': 9,
#  'five month': 9,
#  'tuesday morning': 9,
#  'several day': 9,
#  'delaware': 9,
#  'beverly hill': 9,
#  'watchdog': 9,
#  'cohens testimony': 9,
#  'michael cohens': 9,
#  'senate judiciary committee': 9,
#  'cbs': 9,
#  'last day': 9,
#  'state': 9,
#  'couple day': 9,
#  'eighth': 9,
#  'social medium platform': 9,
#  'year year': 9,
#  'previous year': 9,
#  'ginsburg': 9,
#  'chuck grassley': 9,
#  'twelve': 9,
#  'mercury': 9,
#  'robinson': 9,
#  'new zealander': 9,
#  'milwaukee': 9,
#  'early february': 9,
#  'series': 9,
#  'united state america': 9,
#  'john': 9,
#  'abrams': 9,
#  'jennifer gonnerman': 9,
#  'muslim american': 9,
#  'farhana yamin': 9,
#  'later day': 9,
#  'north kivu': 9,
#  'yahoo news': 9,
#  'dershowitz': 9,
#  'billion year': 9,
#  'toyota': 9,
#  'lien': 9,
#  'southern california': 9,
#  'sol pais': 9,
#  'antarctica': 9,
#  'somali': 9,
#  'baker': 9,
#  'stephen paddock': 9,
#  'johnny walker': 9,
#  'judy woodruff': 9,
#  'st luke': 9,
#  'u news': 9,
#  'david wohl': 9,
#  'douglas': 9,
#  'dan mccready': 8,
#  'rupert murdoch': 8,
#  'west': 8,
#  'earlier day': 8,
#  'forbes': 8,
#  'measles': 8,
#  'liaison office': 8,
#  'jakarta': 8,
#  'birmingham': 8,
#  'congress week': 8,
#  'gore': 8,
#  'four million': 8,
#  'visa': 8,
#  'one week': 8,
#  'technician': 8,
#  'omar albashir': 8,
#  'protester': 8,
#  'george pell': 8,
#  'monday afternoon': 8,
#  'u navy': 8,
#  'maga': 8,
#  'south america': 8,
#  'jpmorgan': 8,
#  'obamaera': 8,
#  'four year ago': 8,
#  'discovery': 8,
#  'vekselberg': 8,
#  'four hour': 8,
#  'weld': 8,
#  'lincoln': 8,
#  'democrat party': 8,
#  'last thursday': 8,
#  'john robert': 8,
#  'red cross': 8,
#  'dutch': 8,
#  'north american': 8,
#  'six week': 8,
#  'roe v wade': 8,
#  'last april': 8,
#  'elena kagan': 8,
#  'tom fitton': 8,
#  'npr': 8,
#  'thedcnf': 8,
#  'farright': 8,
#  'bayer': 8,
#  'hill': 8,
#  'elizabeth': 8,
#  'ivt': 8,
#  'andrew cuomo': 8,
#  'roughly percent': 8,
#  'several decade': 8,
#  'england': 8,
#  'leana wen': 8,
#  'several month': 8,
#  'foreign ministry': 8,
#  'highpoverty': 8,
#  'time warner': 8,
#  'alex jones': 8,
#  'united': 8,
#  'serbian': 8,
#  'vucic': 8,
#  'congo': 8,
#  'elizabeth warren dmass': 8,
#  'coming month': 8,
#  'al gore': 8,
#  'st louis': 8,
#  'prague': 8,
#  'david pecker': 8,
#  'bernie supporter': 8,
#  'peter': 8,
#  'federal trade commission': 8,
#  'san antonio': 8,
#  'kilimnik': 8,
#  'pan': 8,
#  'oklahoma': 8,
#  'kraus': 8,
#  'getty image': 8,
#  'elsisi': 8,
#  'archdiocese': 8,
#  'two day later': 8,
#  'crowley': 8,
#  'maria butina': 8,
#  'trump tower': 8,
#  'west coast': 8,
#  'lorber': 8,
#  'david sirota': 8,
#  'david brook': 8,
#  'web browser': 8,
#  'abraham gutman abgutman': 8,
#  'david rutz': 8,
#  'hildenbrand': 8,
#  'tech company': 7,
#  'year earlier': 7,
#  'state board': 7,
#  'last december': 7,
#  'three week': 7,
#  'mississippi river': 7,
#  'nicaragua': 7,
#  'helmsburton': 7,
#  'kevin mccarthy': 7,
#  'mccarthy': 7,
#  'years': 7,
#  'david': 7,
#  'cairo': 7,
#  'authority': 7,
#  'le hour': 7,
#  'trump kim': 7,
#  'john f kennedy': 7,
#  'weisselberg': 7,
#  'serf': 7,
#  'one month': 7,
#  'martha gimbel': 7,
#  'reggie walton': 7,
#  'walton': 7,
#  'michele bachmann': 7,
#  'de moines': 7,
#  'overnight': 7,
#  'deutch': 7,
#  'dong dang': 7,
#  'past week': 7,
#  'roughly billion': 7,
#  'fox friend': 7,
#  'max aircraft': 7,
#  'khanna': 7,
#  'last four year': 7,
#  'early april': 7,
#  'gina haspel': 7,
#  'rockland county': 7,
#  'pediatrician': 7,
#  'messitte': 7,
#  'indianapolis': 7,
#  'richard burr': 7,
#  'one night': 7,
#  'ed markey': 7,
#  'sarah': 7,
#  'last september': 7,
#  'sdny': 7,
#  'justice': 7,
#  'pirro': 7,
#  'mick mulvaney': 7,
#  'trillion dollar': 7,
#  'sunday night': 7,
#  'federal court': 7,
#  'new york post': 7,
#  'midwestern': 7,
#  'ross': 7,
#  'tim kaine': 7,
#  'far year': 7,
#  'anthony kennedy': 7,
#  'fox news channel': 7,
#  'late tuesday': 7,
#  'new delhi': 7,
#  'national guard': 7,
#  'goldman sachs': 7,
#  'american university': 7,
#  'columbia university': 7,
#  'baier': 7,
#  'arabic': 7,
#  'jeff': 7,
#  'jews': 7,
#  'stimson': 7,
#  'steele dossier': 7,
#  'arthur': 7,
#  'richard spencer': 7,
#  'ben': 7,
#  'socialist': 7,
#  ...}

# %%
unique_ents = list(sorted_ents.keys())

# %%
unique_ents[0:2]
# Out:
# ['one', 'american']

# %% [markdown]
# ## Creating sentiment columns

# %%
for ent in unique_ents[0:50]:
    body_df[ent] = body_df['Body'].apply(lambda x: extract_get_sentiment(ent, x))

# %%
body_df.head()

# %% [markdown]
# ## Saving processed df

# %%
body_df.to_csv('preprocess2.csv')

# %% [markdown]
# ## Loading processed df

# %% [markdown]
# ## Regression Model
