# %% [markdown]
# ## Importing Libraries

# %%
# Data Analysis and Processing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
from collections import Counter

# Natural Language Processing
### General
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
import string

### Sentiment Analysis
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

### Part of Speech Tagging
import spacy
nlp = spacy.load('en_core_web_sm')

# Modelling
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Evaluation
from scipy import stats
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/chingyiie/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Function Definitions

# %%
def get_sentiment(text):
    # gets the compound score of the sentiment using the VADER lexicon
    sid = SentimentIntensityAnalyzer()
    
    results = sid.polarity_scores(text)
    sentiment = results['compound']
    return sentiment

# %%
def get_entities(text):
    # gets the entities from the sentence and returns a list of them
    doc = nlp(text)
    return list(doc.ents)

# %%
def extract_sentences(word, text):
    # extract all sentences in text in which word appears
    sentences = [sentence for sentence in text.split('.') if word in sentence]
    return sentences

# %%
def extract_get_sentiment(word, text):
    # returns aggregate of sentiment for all sentences that contains word in text
    text = text.lower()
    word = word.lower()
    
    sentiments = [get_sentiment(sentence) for sentence in extract_sentences(word, text)]
    
    if len(sentiments) > 1:
        return mean(sentiments)
    return 0

# %% [markdown]
# ## NLP Use Example

# %%
sentence = 'Trump is a horrible president, Trump, Bernie Sanders are equally bad'

# %%
get_sentiment(sentence)
# Out:
# -0.7906

# %%
get_entities(sentence)
# Out:
# [Trump, Trump, Bernie Sanders]

# %%
extract_sentences('one', 'hello one who. There one')
# Out:
# ['hello one who', ' There one']

# %%
extract_get_sentiment('trump', 'Trump is good. Trump sucks. Hello there')
# Out:
# 0.039599999999999996

# %% [markdown]
# ## Importing Data

# %%
#df = pd.read_csv("../data/final_data.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
body_df = df.drop(columns=['Url', 'Author', 'Date', 'Header', 'Source', 'n_links', 'Quality'])

# %%
body_df.head()
# Out:
#                                                 Body   Bias
# 0  Abortion rights advocates have asked the U.S. ...   1.67
# 1  A federal appeals court rejected the most dire...   0.67
# 2  As part of the Trump administration's effort t...  -2.75
# 3  President Donald Trump and "the Trump of the T...  -4.33
# 4  U.S Senator Elizabeth Warren, who is competing... -10.00

# %%
def process_text(text):
    # 1. Lowercase text
    # 2. Removes punctuation
    # 3. Removes stopwords
    # 4. Lemmatizes remaining words

    text = text.lower()
    
    # removes punctuation
    #nopunc_digit = [char for char in text if char not in string.punctuation and not char.isdigit()]
    #nopunc_digit = ''.join(nopunc_digit)
    nopunc_digit = text
    
    # removes stopwords and lemmatizes remaining words
    wnl = WordNetLemmatizer()
    lemmatized = [wnl.lemmatize(word) for word in nopunc_digit.split() if not wnl.lemmatize(word) in set(stopwords.words('english'))]
    lemmatized = ' '.join(lemmatized)
    
    return lemmatized

# %%
body_df['cleaned_body'] = body_df['Body'].apply(lambda x: process_text(x))

# %% [markdown]
# ## Saving processed df

# %%
#body_df.to_csv('../data/preprocess1.csv', index=False)

# %% [markdown]
# ## Loading processed df

# %%
body_df = pd.read_csv('../data/preprocess1.csv')

# %% [markdown]
# ## Extracting Entities

# %%
all_body = body_df['cleaned_body']

# %%
all_entities = []
for text in all_body:
    ents = get_entities(text)
    all_entities.append(ents)

# %%
flat_entities = [str(item) for sublist in all_entities for item in sublist]

# %%
ents_dict = Counter(flat_entities)
sorted_ents = {k: v for k, v in sorted(ents_dict.items(), reverse=True, key=lambda item: item[1])}

# %%
sorted_ents
# Out:
# {'one': 2298,
#  'trump': 2104,
#  'u.s.': 1606,
#  'two': 1208,
#  'cohen': 1179,
#  'american': 1169,
#  'first': 1109,
#  'republican': 1039,
#  'democrat': 965,
#  'congress': 964,
#  'tuesday': 954,
#  'russian': 696,
#  '2016': 608,
#  'russia': 604,
#  'white house': 601,
#  'new york': 598,
#  'donald trump': 583,
#  'democratic': 535,
#  'today': 515,
#  'senate': 465,
#  'three': 454,
#  'washington': 453,
#  'second': 448,
#  'doe': 421,
#  'america': 418,
#  'last year': 407,
#  'china': 398,
#  'monday': 393,
#  'fbi': 362,
#  'house': 357,
#  'united state': 355,
#  '2020': 352,
#  'north korea': 330,
#  'wednesday': 329,
#  'barr': 314,
#  'last week': 306,
#  '2018': 282,
#  'california': 281,
#  'kim': 263,
#  '2017': 262,
#  'muslim': 252,
#  'new zealand': 252,
#  'cnn': 235,
#  'wa': 234,
#  'mueller': 224,
#  'united states': 219,
#  'four': 218,
#  'clinton': 214,
#  'chinese': 211,
#  'gop': 208,
#  'florida': 205,
#  'boeing': 205,
#  'third': 201,
#  'democrats': 200,
#  'venezuela': 199,
#  'thursday': 196,
#  'omar': 191,
#  'supreme court': 188,
#  'michael cohen': 182,
#  'fox news': 179,
#  'israel': 178,
#  'moscow': 177,
#  'justice department': 173,
#  'iran': 168,
#  'french': 167,
#  'yemen': 165,
#  'hillary clinton': 162,
#  'north korean': 161,
#  'saudi': 159,
#  'texas': 155,
#  'last month': 155,
#  'vietnam': 153,
#  'year': 152,
#  'amy goodman': 152,
#  'warren': 151,
#  'five': 147,
#  'france': 144,
#  'robert mueller': 136,
#  'harris': 134,
#  'friday': 134,
#  'dozen': 132,
#  'republicans': 128,
#  'half': 127,
#  'cuba': 127,
#  'americans': 125,
#  'daily': 125,
#  'jewish': 124,
#  'british': 123,
#  'britain': 122,
#  'venezuelan': 120,
#  'morning': 119,
#  'thousand': 118,
#  'iowa': 118,
#  'chicago': 117,
#  'europe': 117,
#  'hundred': 116,
#  'india': 116,
#  'brazil': 115,
#  'january': 115,
#  'eu': 115,
#  'washington post': 114,
#  'european': 114,
#  'lawmaker': 114,
#  'christian': 113,
#  '2014': 112,
#  'yesterday': 112,
#  'mexico': 111,
#  'week': 111,
#  '2015': 108,
#  'six': 108,
#  'iraq': 108,
#  'saudi arabia': 107,
#  'north carolina': 106,
#  'million': 105,
#  'fed': 105,
#  'pakistan': 103,
#  'kim jong un': 102,
#  'earlier month': 99,
#  'sunday': 99,
#  '50': 99,
#  'new york city': 98,
#  'cia': 97,
#  'london': 97,
#  'kraft': 97,
#  'indian': 96,
#  'medicare': 95,
#  'hanoi': 95,
#  'elizabeth warren': 94,
#  '2012': 93,
#  '2019': 91,
#  'obama': 91,
#  '10': 91,
#  'syria': 91,
#  '5': 89,
#  'december': 89,
#  'maryland': 89,
#  'afghanistan': 89,
#  'new jersey': 86,
#  'u': 86,
#  '737': 86,
#  '2': 86,
#  'zero': 85,
#  'manhattan': 84,
#  '1': 84,
#  'february': 83,
#  'night': 83,
#  '100': 83,
#  'paris': 83,
#  'navy': 82,
#  'maduro': 81,
#  'deutsche bank': 81,
#  'faa': 81,
#  'johnson': 80,
#  'march 19, 2019': 78,
#  'israeli': 77,
#  'reuters': 76,
#  'april 17, 2019': 76,
#  'massachusetts': 75,
#  'annual': 75,
#  'pentagon': 75,
#  'japan': 74,
#  'nra': 74,
#  'ilhan omar': 72,
#  'democratic party': 72,
#  'kamala harris': 71,
#  '9/11': 71,
#  'putin': 71,
#  'ohio': 71,
#  'amazon': 71,
#  '3': 71,
#  '2013': 70,
#  'month': 70,
#  'eight': 70,
#  'islamic': 69,
#  '2008': 69,
#  'notre dame': 69,
#  '20': 68,
#  'day': 68,
#  '2010': 68,
#  'flynn': 68,
#  'seven': 67,
#  'uk': 67,
#  'english': 67,
#  'bolsonaro': 66,
#  'virginia': 66,
#  'november': 66,
#  'colorado': 66,
#  '200': 66,
#  'los angeles': 66,
#  'european union': 66,
#  'australia': 66,
#  'evening': 65,
#  'nbc news': 65,
#  'october': 64,
#  'nancy pelosi': 64,
#  'wall street journal': 64,
#  'fox': 63,
#  'calif.': 62,
#  'capitol hill': 61,
#  'donald j. trump': 61,
#  'u.k.': 61,
#  'korean': 59,
#  '15': 59,
#  'recent years': 59,
#  'san francisco': 59,
#  'alexandria': 59,
#  'mulvaney': 59,
#  'beto': 58,
#  'brexit': 58,
#  'wohl': 58,
#  'pennsylvania': 57,
#  'march': 57,
#  'germany': 57,
#  '2011': 56,
#  'le': 56,
#  'two year': 56,
#  'palestinian': 56,
#  'marijuana': 55,
#  'ukraine': 55,
#  'miller': 54,
#  'minnesota': 54,
#  'us': 54,
#  'south korea': 54,
#  'notre': 54,
#  'cuban': 53,
#  'february 26, 2019': 53,
#  'saturday': 53,
#  'apple': 53,
#  'conway': 53,
#  'william barr': 52,
#  'australian': 52,
#  'kushner': 52,
#  'three year': 52,
#  'years': 52,
#  'brazilian': 51,
#  'joe biden': 51,
#  'castro': 51,
#  'iranian': 51,
#  'arizona': 51,
#  'hollywood': 51,
#  'bush': 51,
#  'john mccain': 50,
#  'barack obama': 50,
#  'jordan': 50,
#  'williams': 49,
#  'singapore': 49,
#  'pyongyang': 49,
#  'decades': 49,
#  'associated press': 49,
#  '18': 49,
#  'bill': 49,
#  'german': 49,
#  'nebraska': 48,
#  'beijing': 48,
#  'south carolina': 48,
#  'wojcicki': 48,
#  '0%': 48,
#  '100,000': 47,
#  'state department': 47,
#  'at&t': 47,
#  'tennessee': 47,
#  'hour': 46,
#  'bernie sander': 46,
#  'irs': 46,
#  'indiana': 46,
#  '2007': 46,
#  'vladimir putin': 46,
#  'nine': 46,
#  'treasury': 46,
#  'matt gaetz': 46,
#  'manafort': 46,
#  'mcconnell': 46,
#  'yanukovych': 46,
#  '4': 45,
#  'june': 45,
#  'mexican': 45,
#  'donald trump jr.': 45,
#  'pete buttigieg': 44,
#  '1,000': 44,
#  '1996': 44,
#  'georgia': 44,
#  'mitch mcconnell': 44,
#  'graham': 44,
#  'buttigieg': 43,
#  'google': 43,
#  'smollett': 43,
#  'kremlin': 43,
#  'mike pompeo': 43,
#  '40': 43,
#  'wisconsin': 43,
#  'illinois': 42,
#  'south korean': 42,
#  '13': 42,
#  'monday night': 42,
#  'sudan': 42,
#  'one day': 42,
#  '2009': 42,
#  'pecker': 42,
#  'roger stone': 41,
#  'missouri': 41,
#  'african-american': 41,
#  'republican party': 41,
#  'michigan': 41,
#  'canada': 41,
#  'ten thousand': 41,
#  'february 27, 2019': 41,
#  'kashmir': 41,
#  'winter': 41,
#  'pakistani': 41,
#  'gaetz': 41,
#  'qualcomm': 41,
#  'new hampshire': 41,
#  'maine': 40,
#  'turkey': 40,
#  'ukrainian': 40,
#  'pell': 40,
#  'macron': 40,
#  'west virginia': 40,
#  'six4three': 40,
#  'donald': 39,
#  'cohen wa': 39,
#  'april': 39,
#  'juan gonzález': 39,
#  'norway': 39,
#  'senate intelligence committee': 38,
#  'arab': 38,
#  'd.c.': 38,
#  'new york times': 38,
#  'bernie': 38,
#  'de blasio': 38,
#  'vermont': 37,
#  'army': 37,
#  'msnbc': 37,
#  '8': 37,
#  'gonzalez': 37,
#  'next year': 37,
#  'fourth': 37,
#  'louisiana': 36,
#  'klobuchar': 36,
#  'moon': 36,
#  'bill clinton': 36,
#  'catholic': 36,
#  'paul manafort': 36,
#  '25': 36,
#  'boston': 36,
#  'indonesia': 36,
#  '14': 36,
#  'tonight': 36,
#  'afternoon': 36,
#  'isi': 36,
#  '12': 36,
#  'silicon valley': 36,
#  'connecticut': 35,
#  'max': 35,
#  'nbc': 35,
#  'jared kushner': 35,
#  'pais': 35,
#  '16': 34,
#  'anti-muslim': 34,
#  '30': 34,
#  'world war ii': 34,
#  'intel': 34,
#  '17': 34,
#  'months': 34,
#  'denver': 34,
#  'wolf': 34,
#  'medicaid': 33,
#  'japanese': 33,
#  'biden': 33,
#  'george w. bush': 33,
#  'colombia': 32,
#  'two years': 32,
#  'white supremacist': 32,
#  'five year': 32,
#  'jacinda ardern': 32,
#  'africa': 32,
#  'somalia': 32,
#  'bernie sanders': 32,
#  'last summer': 32,
#  'asian': 32,
#  'sec': 32,
#  'summer': 32,
#  'microsoft': 32,
#  'kentucky': 31,
#  '$1 million': 31,
#  'three-year': 31,
#  'mccain': 31,
#  'southern district': 31,
#  'alabama': 31,
#  'fifth': 31,
#  '10,000': 31,
#  'garcia': 31,
#  'decade': 31,
#  'authority': 31,
#  '2006': 31,
#  'smith': 31,
#  'cory booker': 31,
#  'nevada': 31,
#  'russians': 31,
#  '11': 31,
#  'every day': 31,
#  'norwegian': 31,
#  '24 hour': 30,
#  'two-thirds': 30,
#  'lighthizer': 30,
#  'june 2016': 30,
#  'african american': 30,
#  'earth': 30,
#  'conservatives': 30,
#  'last night': 30,
#  'kazakhstan': 30,
#  'fda': 30,
#  'ftc': 30,
#  'tomorrow': 29,
#  'yang': 29,
#  'pompeo': 29,
#  'year ago': 29,
#  'million dollar': 29,
#  '1999': 29,
#  'n.y.': 29,
#  'earlier year': 29,
#  'brooklyn': 29,
#  'instagram': 29,
#  'district columbia': 29,
#  'wikileaks': 29,
#  '35,000': 29,
#  'september': 29,
#  'muslims': 29,
#  'propublica': 29,
#  'iraqi': 29,
#  'trump administration': 28,
#  'april 16, 2019': 28,
#  'house judiciary committee': 28,
#  'yemeni': 28,
#  'monthly': 28,
#  'weekend': 28,
#  'african': 28,
#  'august': 28,
#  'kelly': 28,
#  '10 year': 27,
#  'fixer': 27,
#  'pelosi': 27,
#  'mosque': 27,
#  'jupiter': 27,
#  '27': 27,
#  'hundred thousand': 27,
#  'miami': 27,
#  'middle east': 27,
#  'oakland': 27,
#  'penny': 27,
#  '300': 27,
#  'peru': 27,
#  'breyer': 27,
#  'gonzalez carranza': 27,
#  'amy klobuchar': 27,
#  'mississippi': 27,
#  'morgan stanley': 27,
#  'vrablic': 27,
#  'three day': 26,
#  'democratic national committee': 26,
#  'midwest': 26,
#  'next week': 26,
#  'tower moscow': 26,
#  'jim jordan': 26,
#  'past year': 26,
#  'fla.': 26,
#  'meadow': 26,
#  'hhs': 26,
#  'mike penny': 26,
#  '21': 26,
#  'asia': 26,
#  '19': 26,
#  'vatican': 26,
#  'jews': 26,
#  'netanyahu': 26,
#  'feinstein': 26,
#  'sirota': 26,
#  'zinke': 26,
#  "o'rourke": 25,
#  'quarterly': 25,
#  'south dakota': 25,
#  'oregon': 25,
#  '2000': 25,
#  '80%': 25,
#  '1998': 25,
#  'amy': 25,
#  'last fall': 25,
#  'nazi': 25,
#  'neo-nazis': 25,
#  'sanchez': 25,
#  'kohl': 25,
#  '90 percent': 24,
#  'two day': 24,
#  '2004': 24,
#  'susan collins': 24,
#  'american civil liberty union': 24,
#  'egypt': 24,
#  'vietnamese': 24,
#  'canadian': 24,
#  '$1 billion': 24,
#  'journal': 24,
#  '500': 24,
#  'carlson': 24,
#  '2005': 24,
#  'kramer': 24,
#  'r.': 24,
#  'usa today': 24,
#  '1 percent': 24,
#  'puerto rico': 24,
#  'bezos': 24,
#  'abc news': 23,
#  '20 percent': 23,
#  '10 percent': 23,
#  'booker': 23,
#  'alexandria ocasio': 23,
#  '1994': 23,
#  'spain': 23,
#  'billion dollar': 23,
#  '2003': 23,
#  'james comey': 23,
#  'mark meadow': 23,
#  'next month': 23,
#  '6': 23,
#  'next day': 23,
#  'later year': 23,
#  'swedish': 23,
#  'stone': 23,
#  '60': 23,
#  'ethiopian': 23,
#  'phillips': 23,
#  'jair bolsonaro': 22,
#  'nato': 22,
#  '1992': 22,
#  'united nation': 22,
#  'alaska': 22,
#  'united kingdom': 22,
#  'two decades': 22,
#  'two year ago': 22,
#  'mcgahn': 22,
#  'elijah cummings': 22,
#  'late last year': 22,
#  'july 2017': 22,
#  'rudy giuliani': 22,
#  'cbs news': 22,
#  'recent year': 22,
#  'cummings': 22,
#  'italian': 22,
#  'utah': 22,
#  'new mexico': 22,
#  'jew': 22,
#  'homer': 22,
#  'muthana': 22,
#  'bayoumi': 22,
#  'gallup': 22,
#  'kellyanne conway': 22,
#  'george conway': 22,
#  'jefferson county': 22,
#  'hildenbrand': 22,
#  'rod rosenstein': 21,
#  'last november': 21,
#  'hispanic': 21,
#  'first quarter': 21,
#  'social medium': 21,
#  'italy': 21,
#  '30 percent': 21,
#  'xi jinping': 21,
#  'brussels': 21,
#  '400': 21,
#  'indonesian': 21,
#  '2001': 21,
#  'lindsey graham': 21,
#  'buzzfeed news': 21,
#  'houston': 21,
#  'qatar': 21,
#  'julian': 21,
#  'kagan': 21,
#  'harvard': 21,
#  'sweden': 21,
#  'bitcoin': 21,
#  'algorithm': 21,
#  'berlin': 21,
#  'martin county': 21,
#  'nasa': 21,
#  'spoor': 21,
#  'trump wa': 20,
#  'june 2017': 20,
#  'turkish': 20,
#  '10 years': 20,
#  '20,000': 20,
#  'july': 20,
#  'weekly': 20,
#  'rosenstein': 20,
#  'assange': 20,
#  'hill': 20,
#  '7': 20,
#  'parliament': 20,
#  '50,000': 20,
#  'stanford': 20,
#  '70 percent': 20,
#  'd.': 20,
#  'latin america': 19,
#  '200,000': 19,
#  "beto o'rourke": 19,
#  'jamal khashoggi': 19,
#  'palm beach county': 19,
#  '5,000': 19,
#  'khashoggi': 19,
#  'annually': 19,
#  'u.n.': 19,
#  'davis': 19,
#  'april 15, 2019': 19,
#  '1970s': 19,
#  '3 percent': 19,
#  'every year': 19,
#  'app': 19,
#  'epa': 19,
#  'colombian': 19,
#  'nigerian': 19,
#  '22': 19,
#  'giuliani': 19,
#  'yale': 19,
#  'cuomo': 19,
#  '40 percent': 19,
#  'ted cruz': 19,
#  'ecuador': 19,
#  'monsanto': 19,
#  'newton': 19,
#  'sander': 19,
#  'dowless': 19,
#  'hollings': 19,
#  '130,000': 18,
#  'korea': 18,
#  'house intelligence committee': 18,
#  'jr': 18,
#  '$3 billion': 18,
#  'dems': 18,
#  'hernandez': 18,
#  'four year': 18,
#  '35': 18,
#  'emmanuel macron': 18,
#  'north dakota': 18,
#  'native american': 18,
#  'august 2018': 18,
#  'thomas': 18,
#  'rome': 18,
#  'stephen miller': 18,
#  '100 percent': 18,
#  'atlantic': 18,
#  'islam': 18,
#  'michael sanchez': 18,
#  'guardian': 18,
#  'tucker carlson': 18,
#  'april 13, 2019': 18,
#  'seattle': 18,
#  'michael t. flynn': 18,
#  'luke': 18,
#  'mark harris': 17,
#  'january 2017': 17,
#  'abc': 17,
#  'february 2018': 17,
#  'lisa murkowski': 17,
#  'authoritarian': 17,
#  'bolton': 17,
#  'house oversight committee': 17,
#  'lanny davis': 17,
#  'bashir': 17,
#  'bbc': 17,
#  'two month': 17,
#  'un': 17,
#  '60 percent': 17,
#  'ethiopia': 17,
#  '2,000': 17,
#  'april 2018': 17,
#  'juan guaidó': 17,
#  'lebanon': 17,
#  'bronx': 17,
#  'sanctuary city': 17,
#  'soviet union': 17,
#  'jim crow': 17,
#  'irish': 17,
#  'comey': 17,
#  'cordray': 17,
#  '9': 16,
#  'last august': 16,
#  'chuck schumer': 16,
#  'thom tillis': 16,
#  'wyden': 16,
#  '2002': 16,
#  'communist': 16,
#  'r-ky.': 16,
#  'january 2016': 16,
#  '80 percent': 16,
#  'jpmorgan': 16,
#  '23': 16,
#  'shedd': 16,
#  'past decade': 16,
#  '5 month': 16,
#  'marco rubio': 16,
#  'martin': 16,
#  'u.s. supreme court': 16,
#  'march 18, 2019': 16,
#  'bill de blasio': 16,
#  'july 2016': 16,
#  'first day': 16,
#  'december 2017': 16,
#  '58': 16,
#  'baltimore': 16,
#  'reagan': 16,
#  'theresa': 16,
#  'hoda muthana': 16,
#  'solidarity': 16,
#  '33': 16,
#  'nazarbayev': 16,
#  'anderson': 16,
#  'crowley': 16,
#  'moynihan': 16,
#  'dnc': 15,
#  '24': 15,
#  'sixth': 15,
#  '245': 15,
#  'tillis': 15,
#  '49': 15,
#  'august 2016': 15,
#  'eighth': 15,
#  'homeland security': 15,
#  'adam schiff': 15,
#  '50 percent': 15,
#  'six year': 15,
#  'last two years': 15,
#  '54': 15,
#  'alito': 15,
#  '1976': 15,
#  'recent weeks': 15,
#  'bos': 15,
#  'philadelphia': 15,
#  'central american': 15,
#  'ten': 15,
#  'george papadopoulos': 15,
#  'lee': 15,
#  'pirro': 15,
#  'brett kavanaugh': 15,
#  'six month': 15,
#  'daily caller news foundation': 15,
#  'jones': 15,
#  'central america': 15,
#  'ford': 15,
#  'syrian': 15,
#  'jane': 15,
#  'decade ago': 15,
#  'ronald reagan': 15,
#  'two-year': 15,
#  'ap': 15,
#  'united methodist church': 15,
#  'dershowitz': 15,
#  'little $3 $': 15,
#  'michael d. cohen': 15,
#  'nunes': 15,
#  'sanders': 15,
#  'steese': 15,
#  'va': 15,
#  'krueger': 15,
#  'three month': 14,
#  'sarah sander': 14,
#  'mitt romney': 14,
#  '9th': 14,
#  '$100 million': 14,
#  'defense department': 14,
#  'minute': 14,
#  '20 years': 14,
#  '77': 14,
#  '500,000': 14,
#  "donald trump's": 14,
#  'mohammed bin salman': 14,
#  'coming weeks': 14,
#  'last october': 14,
#  'michael flynn': 14,
#  'vox': 14,
#  'adam': 14,
#  'trump kim': 14,
#  'central bank': 14,
#  '$2 billion': 14,
#  'hillary': 14,
#  '38': 14,
#  'interior': 14,
#  'samuel alito': 14,
#  'ibm': 14,
#  '21st century': 14,
#  'hundred million dollar': 14,
#  'guy': 14,
#  'election day': 14,
#  'al qaeda': 14,
#  'early 1990s': 14,
#  'spanish': 14,
#  'king': 14,
#  'benjamin netanyahu': 14,
#  'quarter': 14,
#  '1991': 14,
#  'scotland': 14,
#  'bethlehem': 14,
#  'january 2018': 14,
#  'carter': 14,
#  'nearly half': 14,
#  'yoruba': 14,
#  'abrams': 14,
#  'first year': 14,
#  'daley': 14,
#  '1960s': 14,
#  '2 percent': 14,
#  'matt': 14,
#  'two week': 14,
#  'powell': 14,
#  '55': 14,
#  'briggs': 14,
#  'ac': 14,
#  'scandinavian': 14,
#  'al-nashiri': 14,
#  'offit': 14,
#  'american independent foundation': 14,
#  'musk': 14,
#  'every 12 week': 14,
#  'noise daily news': 14,
#  'analyse': 14,
#  'jacob wohl': 14,
#  'jeff sessions': 13,
#  'jay inslee': 13,
#  '4%': 13,
#  'christopher steele': 13,
#  'five years': 13,
#  'detroit': 13,
#  'three years': 13,
#  'dc': 13,
#  'switzerland': 13,
#  'john bolton': 13,
#  'united arab': 13,
#  'aaron': 13,
#  '25 percent': 13,
#  'ag': 13,
#  'egyptian': 13,
#  'madrid': 13,
#  'weld': 13,
#  '30%': 13,
#  '30 year': 13,
#  'protester': 13,
#  'kim jong-un': 13,
#  'tuesday night': 13,
#  'stephen breyer': 13,
#  '7 percent': 13,
#  'gao': 13,
#  '5 percent': 13,
#  'devin nunes': 13,
#  'recent months': 13,
#  '737 max': 13,
#  'may 2017': 13,
#  'obama-era': 13,
#  'defense': 13,
#  '26': 13,
#  'la vegas': 13,
#  'hulu': 13,
#  'poland': 13,
#  'control house': 13,
#  '20%': 13,
#  'kirsten gillibrand': 13,
#  'jerusalem': 13,
#  'two dozen': 13,
#  'el paso': 13,
#  'new yorker': 13,
#  '42': 13,
#  'baier': 13,
#  'national guard': 13,
#  'march 29': 13,
#  'month later': 13,
#  'national assembly': 13,
#  'november 2017': 13,
#  'tehran': 13,
#  'vucic': 13,
#  'ingraham': 13,
#  'lesbian': 13,
#  'federal reserve': 13,
#  'thirteen': 13,
#  'hardeman': 13,
#  'orange county': 13,
#  'russo': 13,
#  'william brangham': 13,
#  'shen yun': 13,
#  'https://www.vanityfair.com/video/watch/how-a-celebrity-trainer-gets-actors-in-shape-for-movies/': 13,
#  'refuse quiet': 13,
#  'three-day': 12,
#  '1%': 12,
#  '$10 million': 12,
#  'tuesday afternoon': 12,
#  'meghan': 12,
#  '36': 12,
#  '2.0': 12,
#  'inter-korean': 12,
#  '600': 12,
#  'state': 12,
#  'end day': 12,
#  'eight year': 12,
#  'vekselberg': 12,
#  'buzzfeed': 12,
#  'last june': 12,
#  'toledo': 12,
#  '47': 12,
#  'earlier tuesday': 12,
#  'bloomberg': 12,
#  'senate judiciary committee': 12,
#  'western': 12,
#  'party': 12,
#  'charleston': 12,
#  'alikhan': 12,
#  'warner': 12,
#  'al noor mosque': 12,
#  'fifty': 12,
#  'airbus': 12,
#  '$5.7 billion': 12,
#  'collins': 12,
#  'february 2017': 12,
#  'one two': 12,
#  'millions': 12,
#  '1986': 12,
#  'palestinians': 12,
#  'west bank': 12,
#  'june 2018': 12,
#  'npr': 12,
#  'robinson': 12,
#  'december 2018': 12,
#  'october 2017': 12,
#  '63': 12,
#  'england': 12,
#  'pence': 12,
#  'tarrant': 12,
#  'next decade': 12,
#  'john': 12,
#  '3.0': 12,
#  'libya': 12,
#  'la vega': 12,
#  'matthew': 12,
#  '300,000': 12,
#  'serbia': 12,
#  'jr.': 12,
#  'pro-russian': 12,
#  'patton': 12,
#  'n.c.': 12,
#  'libertarian': 12,
#  'days': 12,
#  'kaji': 12,
#  '70': 12,
#  'kennedy': 12,
#  'section 230': 12,
#  'mozambique': 12,
#  'chase': 12,
#  'baker': 12,
#  'sater': 12,
#  'howard lorber': 12,
#  'share"></script': 12,
#  'month year': 11,
#  'jeff session': 11,
#  '270': 11,
#  'islamophobic': 11,
#  'robert kraft': 11,
#  'one year': 11,
#  'nfl': 11,
#  '250,000': 11,
#  'recent day': 11,
#  'august 2017': 11,
#  'brenton tarrant': 11,
#  'usa': 11,
#  'latin american': 11,
#  '60,000': 11,
#  'steven mnuchin': 11,
#  'seven year': 11,
#  'democratic rep': 11,
#  'philippine': 11,
#  'jakarta': 11,
#  'five-year': 11,
#  'tokyo': 11,
#  'healthcare': 11,
#  'walton': 11,
#  'n’t': 11,
#  'constitution': 11,
#  '2017 2018': 11,
#  '$500 million': 11,
#  '40,000': 11,
#  'west': 11,
#  'dong dang': 11,
#  'tuesday morning': 11,
#  'three days': 11,
#  'last decade': 11,
#  'south africa': 11,
#  'jeff bezos': 11,
#  '1990': 11,
#  'md.': 11,
#  'hundreds': 11,
#  '10%': 11,
#  '28': 11,
#  '150': 11,
#  'one four': 11,
#  'bill barr': 11,
#  'cbs': 11,
#  'disney': 11,
#  ...}

# %%
unique_ents = list(sorted_ents.keys())

# %%
unique_ents[0:2]
# Out:
# ['one', 'trump']

# %% [markdown]
# ## Creating sentiment columns

# %%
for ent in unique_ents[0:50]:
    body_df[ent] = body_df['cleaned_body'].apply(lambda x: extract_get_sentiment(ent, x))

# %%
body_df.head()
# Out:
#                                                 Body   Bias  \
# 0  Abortion rights advocates have asked the U.S. ...   1.67
# 1  A federal appeals court rejected the most dire...   0.67
# 2  As part of the Trump administration's effort t...  -2.75
# 3  President Donald Trump and "the Trump of the T...  -4.33
# 4  U.S Senator Elizabeth Warren, who is competing... -10.00
#
#                                         cleaned_body       one  american  \
# 0  abortion right advocate asked u.s. supreme cou...  0.000000    0.0000
# 1  federal appeal court rejected direct constitut...  0.171917    0.0000
# 2  part trump administration's effort slow migran...  0.000000    0.0000
# 3  president donald trump "the trump tropics," br...  0.539900    0.0000
# 4  u.s senator elizabeth warren, competing democr...  0.247940    0.5155
#
#       trump      two  republican  democrat     first  ...  clinton  florida  \
# 0  0.000000  0.00000         0.0   0.00000  0.000000  ...      0.0      0.0
# 1  0.359200  0.00000         0.0   0.00000  0.000000  ...      0.0      0.0
# 2 -0.224025  0.00000         0.0   0.00000  0.000000  ...      0.0      0.0
# 3  0.328425  0.29770         0.0   0.00000  0.414833  ...      0.0      0.0
# 4  0.000000  0.44895         0.0   0.37385  0.335250  ...      0.0      0.0
#
#    u.s.     2016    2020     2018  2017        wa   mueller  united states
# 0     0  0.00000  0.0000  0.00000   0.0  0.401000  0.000000          0.000
# 1     0  0.56015  0.0000  0.00000   0.0  0.193687  0.196287          0.000
# 2     0  0.00000  0.0000 -0.20095   0.0 -0.195829  0.000000          0.000
# 3     0  0.00000  0.0000  0.00000   0.0  0.385815  0.000000          0.841
# 4     0  0.00000  0.4117  0.00000   0.0  0.384791  0.000000          0.000
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Saving processed df

# %%
#body_df.to_csv('../data/preprocess2.csv', index=False)

# %% [markdown]
# ## Loading processed df

# %%
body_df = pd.read_csv('../data/preprocess2.csv')

# %% [markdown]
# ## Preprocessing for Model

# %%
X = body_df.drop(columns=['Body', 'cleaned_body', 'Bias'])
y = body_df['Bias']

# %%
col_names = X.columns

scaler = MinMaxScaler()
scaled = scaler.fit_transform(X)
X = pd.DataFrame(scaled, columns=col_names)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## Linear Regression

# %%
# Defining Model
regressor = LinearRegression()
# Training Model
regressor.fit(X_train, y_train)
# Making Predictions
y_pred = regressor.predict(X_test)
# Evaluating
print(stats.pearsonr(y_pred, y_test)[0])
# Out:
# 0.006199810307246947

# %% [markdown]
# ## Lasso Regression

# %%
# Defining Model
lasso = LassoCV(cv=5,
                alphas=np.logspace(-4,1,110),
                max_iter=10000,
                normalize=True)
# Training Model
lasso.fit(X_train, y_train)
# Number of features selected
coeffs = lasso.coef_!=0
coeff_used = np.sum(coeffs)
print('Number of coefficients: ', coeff_used)

# Fitting regressor
regressor.fit(X_train.loc[:, coeffs], y_train)
# Making predictions
y_pred = regressor.predict(X_test.loc[:, coeffs])
# Evaluating
score = stats.pearsonr(y_pred, y_test)[0]
print('Pearson coefficient: ', score)
# Out:
# Number of coefficients:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-4ab3bbfbc200> in <module>
#      12
#      13 # Fitting regressor
# ---> 14 regressor.fit(X_train.loc[:, coeffs], y_train)
#      15 # Making predictions
#      16 y_pred = regressor.predict(X_test.loc[:, coeffs])
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     556                              " a minimum of %d is required%s."
#     557                              % (n_features, array.shape, ensure_min_features,
# --> 558                                 context))
#     559
#     560     if warn_on_dtype and dtype_orig is not None and array.dtype != dtype_orig:
#
# ValueError: Found array with 0 feature(s) (shape=(1256, 0)) while a minimum of 1 is required.

# %%
n = 336
print(body_df['Bias'][n])
extract_get_sentiment('left', body_df['Body'][n])
# Out:
# 40.0
# -0.12184285714285714

# %%
body_df[body_df['Bias'] == max(body_df['Bias'])]
