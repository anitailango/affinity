# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/Interactive Media Bias Chart - Ad Fontes Media.csv')

# %%
sources = df['Source'].unique()
sources
# Out:
# array(['ABC', 'Al Jazeera', 'Alternet', 'American Spectator, The', 'AP',
#        'Axios', 'BBC', 'Bipartisan Report', 'Bloomberg', 'Breitbart',
#        'Business Insider', 'BuzzFeed', 'CBS', 'Christian Science Monitor',
#        'CNN', 'CNSNews', 'Conservative Review', 'Conservative Tribune',
#        'Counterpunch', 'Crooks and Liars', 'Daily Beast', 'Daily Caller',
#        'Daily Kos', 'Daily Mail', 'Daily Signal', 'Daily Wire',
#        'Democracy Now', 'EPI', 'Financial Times', 'Fiscal Times',
#        'Forbes', 'Foreign Policy', 'Fortune', 'Forward', 'Fox News',
#        'FreeSpeech TV', 'Guacamoley', 'Huffington Post', 'IJR',
#        'InfoWars', 'Intercept', 'Jacobin', 'LA Times', 'Life News',
#        'Marketwatch', 'Mother Jones', 'MSNBC', 'National Enquirer',
#        'National Public Radio', 'National Review', 'New Republic',
#        'New York Post', 'New York Times', 'News and Guts', 'NewsMax',
#        'NewsPunch', 'Newsy', 'Occupy Democrats',
#        'One America News Network', 'OZY', 'Palmer Report', 'Patribotics',
#        'PBS', 'PJ Media', 'Politico', 'Progressive, The', 'ProPublica',
#        'Quartz', 'Reason', 'RedState', 'Reuters', 'Second Nexus',
#        'ShareBlue', 'Slate', 'Spoutable', 'Talking Points Memo',
#        'The Advocate', 'The American Conservative', 'The Atlantic',
#        'The Blaze', 'The Economist', 'The Federalist',
#        'The Gateway Pundit', 'The Guardian', 'The Hill', 'The Nation',
#        'The New Yorker', 'The Skimm', 'The Week', 'Think Progress',
#        'Time', 'Truthout', 'Twitchy', 'UrNews24', 'USA Today',
#        'Vanity Fair', 'Vice', 'Vox', 'Wall Street Journal',
#        'Washington Examiner', 'Washington Free Beacon',
#        'Washington Monthly', 'Washington Post', 'Washington Times',
#        'Weather.com', 'Wonkette', 'World Truth TV', 'WorldNetDaily'],
#       dtype=object)

# %%
for source in sources:
    url_list = df[df['Source'] == source]['Url']
    
    filename = '../data/' + source + '_urls.txt'
    
    file = open(filename, 'w')
    for url in url_list:
        file.write(url)
        file.write('\n')
    file.close()
    
    print('finished writing urls for ', source)
# Out:
# finished writing urls for  ABC
# finished writing urls for  Al Jazeera
# finished writing urls for  Alternet
# finished writing urls for  American Spectator, The
# finished writing urls for  AP
# finished writing urls for  Axios
# finished writing urls for  BBC
# finished writing urls for  Bipartisan Report
# finished writing urls for  Bloomberg
# finished writing urls for  Breitbart
# finished writing urls for  Business Insider
# finished writing urls for  BuzzFeed
# finished writing urls for  CBS
# finished writing urls for  Christian Science Monitor
# finished writing urls for  CNN
# finished writing urls for  CNSNews
# finished writing urls for  Conservative Review
